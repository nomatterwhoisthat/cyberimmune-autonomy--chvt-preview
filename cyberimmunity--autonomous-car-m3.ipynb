# %% [markdown]
# # Кибериммунная автономность$\\$Создание конструктивно защищённого автономного наземного транспортного средства$\\$Модуль 3
#
# ## О документе
#
# Версия 1.03
#
# Модуль 3 для регионального этапа соревнований по кибериммунной автономности

# %% [markdown]
# ### Модуль 3. Внедрение блоков функциональной и информационной безопасности
# #### Общая идея
#
# Ключевая идея кибериммунной автономности заключается в том, чтобы уже на этапе проектирования внедрить защиту от кибератак как снаружи, так и изнутри - т.е. через уязвимые бортовые информационные системы.
# Мы исходим из того, что абсолютно защищённых систем не бывает, чем больше и сложнее код, тем проще одним ("плохим") в нём спрятать уязвимости, а другим ("хорошим", но уставшим) эти уязвимости не найти.
#
# Поэтому необходимо сделать так, чтобы наиболее критичный код был отделён от некритичного и протестирован особенно тщательно - таким образом можно снизить вероятность успешной атаки и затруднить задачу атакующим.

# %% [markdown]
# #### Цели и предположения безопасности
#
# ##### Цели безопасности
# Устойчивость кибериммунных систем к атакам выражается в том, что поставленные заказчиком **цели безопасности** (ЦБ) не нарушаются даже в условиях кибератак (снаружи и изнутри).
#
# Для наших автономных машинок заказчиком поставлены следующие ЦБ:
#
# 1. При любых обстоятельствах АНТС осуществляет перемещения в пределах заданных ограничений
#
# 2. При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут
#
# 3. При любых обстоятельствах АНТС оставляет груз только в авторизованном пункте назначения
#
# Ниже используется цифро-буквенное обозначение целей безопасности - например, ЦБ1 - первая цель безопасности из списка выше.
#
# ##### Предположения безопасности
# При этом заказчик согласовал с разработчиками следующие **предположения безопасности** (ПБ) - утверждения о смежных системах, которые снимают с разработчиков часть задач для обеспечения целей безопасности:
#
# 1. При любых обстоятельствах только авторизованный персонал имеет физический доступ к критическим узлам АНТС
#
# 2. При любых обстоятельствах только аутентичные и авторизованные операторы имеют доступ к системе планирования заданий
#
# 3. Аутентичные и авторизованные операторы обладают необходимой квалификацией и являются благонадёжными (т.е. не пытаются намеренно причинить ущерб системе или третьим лицам, используя доступ к АНТС)
#
# Ниже используется цифро-буквенное обозначение предположений безопасности - например, ПБ1 - первое предположение безопасности из списка выше.

# %% [markdown]
# ### Киберпрепятствия
#
# Прежде чем мы начнём внедрять механизмы безопасности, посмотрим, что произойдёт с нашей машинкой, если бортовые системы начнут вести себя не так, как мы ожидаем.
#
# Для этого активируем специальный режим работы системы управления и снова запустим машинку по тому же маршруту, который был в конце модуля 2.
#
# После инициализации системы управления добавьте следующую строку
# ```python
# control_system.enable_surprises()
# ```

# %% [markdown]
# Но вначале нужно из модуля 2 скопировать сюда ваши текущие наработки, а именно ваши реализации классов коммуникационного шлюза (CommunicationGateway), систему навигации (NavigationSystem), управления (ControlSystem), также будем использовать маршрут, который вы создали.

# %%
# вставьте сюда ваш код
# ваш код
from src.control_system import BaseControlSystem
from src.navigation_system import BaseNavigationSystem
from src.communication_gateway import BaseCommunicationGateway
from multiprocessing import Queue
from src.config import SERVOS_QUEUE_NAME
from src.config import CONTROL_SYSTEM_QUEUE_NAME
from src.config import CARGO_BAY_QUEUE_NAME
from src.event_types import Event


class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        servos_q_name = SERVOS_QUEUE_NAME # замените на правильное название очереди
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=BaseControlSystem.event_source_name,
                      destination=servos_q_name,
                      operation="set_speed", parameters=speed
                    ) # замените на код создания сообщения со скоростью для приводов
                           # подсказка, требуемая операция - set_speed

        # отправка сообщения с желаемым направлением
        event_direction = Event(source=BaseControlSystem.event_source_name,
                      destination=servos_q_name,
                      operation="set_direction", parameters=direction
                    ) # замените на код создания сообщения с направлением для приводов
                               # подсказка, требуемая операция - set_direction

        servos_q.put(event_speed)
        servos_q.put(event_direction)  
        
    def _lock_cargo(self):
        """ заблокировать грузовой отсек """
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                    destination=CARGO_BAY_QUEUE_NAME,
                    operation="lock_cargo", parameters= None
                    )
        cargo_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME, 
                    destination=CARGO_BAY_QUEUE_NAME,
                    operation="release_cargo", parameters= None
                    )  
        cargo_q.put(event)      



class CommunicationGateway(BaseCommunicationGateway):
    """CommunicationGateway класс для реализации логики взаимодействия
    с системой планирования заданий

    Работает в отдельном процессе, поэтому создаётся как наследник класса Process
    """
    def _send_mission_to_consumers(self):
        """ метод для отправки сообщения с маршрутным заданием в систему управления """
        
        # имена очередей блоков находятся в файле src/config.py
        # события нужно отправлять в соответствие с диаграммой информационных потоков
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME

        # события передаются в виде экземпляров класса Event, 
        # описание класса находится в файле src/event_types.py
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )

        # поиск в каталоге нужной очереди (в данном случае - системы управления)
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        # отправка события в найденную очередь
        control_q.put(event)    
        


class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):        
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME # замените на правильное название очереди
        event =  Event(source=BaseControlSystem.event_source_name,
                      destination=control_q_name,
                      operation="position_update", parameters=self._position
                    ) # замените на код создания сообщения с координатами для системы управления 
                     # подсказка, требуемая операция - position_update
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)

# %% [markdown]
# Если у вас настроена и работает СУПА, установите в True значение переменной afcs_present

# %%
afcs_present = True

# %% [markdown]
# Поменяем идентификатор машинки для этого модуля

# %%
car_id = "m3"

# %%
# используем то же маршрутное задание, которое было в модуле 2
from time import sleep
from geopy import Point as GeoPoint

from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser

afcs_present = True

car_id = "m3"

# возьмём маршрут из модуля 2
wpl_file = "module_2.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()
print(points)

from src.mission_type import GeoSpecificSpeedLimit
speed_limits = [
    GeoSpecificSpeedLimit(0, 20),
    GeoSpecificSpeedLimit(3, 50),
    GeoSpecificSpeedLimit(6, 20),
    GeoSpecificSpeedLimit(8, 50),
    GeoSpecificSpeedLimit(9, 20),
]


home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

# по аналогии собираем все блоки в одном кузове
system_components = SystemComponentsContainer(
    components=[
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system
    ] if afcs_present else [
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system
    ])

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
#################################

system_components.start()

# ограничение поездки по времени
# параметр sleep - время в секундах,
# настройте этот параметр так, чтобы ваша машинка завершила маршрут
# в случае превышения времени выполнения ячейки на более чем 10 секунд от заданного, 
# допустимо перезапустить вычислительное ядро и повторно выполнить весь блокнот, штрафные очки за это не начисляются
# при условии, что повторный запуск закончился успешно
sleep(30)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [Point(59.8815191, 29.8300481, 0.0), Point(59.8819121, 29.8282993, 0.0), Point(59.8818098, 29.8277092, 0.0), Point(59.8818583, 29.8274088, 0.0), Point(59.8810884, 29.8267436, 0.0), Point(59.8796617, 29.8254454, 0.0), Point(59.8785849, 29.8245013, 0.0), Point(59.8781972, 29.8241472, 0.0), Point(59.8781003, 29.8241258, 0.0), Point(59.8780249, 29.8242867, 0.0), Point(59.8774811, 29.8267651, 0.0), Point(59.8769158, 29.8291469, 0.0), Point(59.8768512, 29.8291361, 0.0), Point(59.8765389, 29.8288143, 0.0), Point(59.8761512, 29.8284817, 0.0), Point(59.8756531, 29.8274866, 0.0), Point(59.8752903, 29.8277186, 0.0), Point(59.8751927, 29.8276126, 0.0), Point(59.875042, 29.8278809, 0.0), Point(59.8751443, 29.8284495, 0.0), Point(59.8751335, 29.8289645, 0.0), Point(59.8749935, 29.8295438, 0.0), Point(59.8747674, 29.829855, 0.0), Point(59.874455, 29.8299837, 0.0), Point(59.8742666, 29.8298872, 0.0)]
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 16:27:12.242488
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][CONTROL] новая скорость 20 (была 0)
# [ИНФО][CONTROL] новое направление 294 (было 0)
# [ИНФО][CONTROL] новое направление 293 (было 294)
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 73 (было 293)
# [ИНФО][CONTROL] новое направление 70 (было 73)
# [ИНФО][CONTROL] новое направление 67 (было 70)
# [ИНФО][CONTROL] новое направление 68 (было 67)
# Process MissionSender-46:
# Process TelemetrySender-47:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/root/cyberimmune-autonomy--chvt-preview/src/mission_planner_mqtt.py", line 162, in run
#     self._mqttc.loop_stop()
#   File "/root/cyberimmune-autonomy--chvt-preview/src/sitl_mqtt.py", line 164, in run
#     self._mqttc.loop_stop()
#   File "/root/cyberimmune-autonomy--chvt-preview/env/lib/python3.12/site-packages/paho/mqtt/client.py", line 1839, in loop_stop
#     self._thread.join()
#   File "/root/cyberimmune-autonomy--chvt-preview/env/lib/python3.12/site-packages/paho/mqtt/client.py", line 1839, in loop_stop
#     self._thread.join()
#   File "/usr/lib/python3.12/threading.py", line 1147, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.12/threading.py", line 1147, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.12/threading.py", line 1167, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/threading.py", line 1167, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 105
#     102 sleep(30)
#     104 # останавливаем все компоненты
# --> 105 system_components.stop()
#     107 # удалим все созданные компоненты
#     108 system_components.clean()
#
# File ~/cyberimmune-autonomy--chvt-preview/src/system_wrapper.py:42, in SystemComponentsContainer.stop(self)
#      39     component.stop()
#      41 for component in self._components:
# ---> 42     component.join()
#
# File /usr/lib/python3.12/multiprocessing/process.py:149, in BaseProcess.join(self, timeout)
#     147 assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148 assert self._popen is not None, 'can only join a started process'
# --> 149 res = self._popen.wait(timeout)
#     150 if res is not None:
#     151     _children.discard(self)
#
# File /usr/lib/python3.12/multiprocessing/popen_fork.py:43, in Popen.wait(self, timeout)
#      41             return None
#      42     # This shouldn't block if wait() returned successfully.
# ---> 43     return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#      44 return self.returncode
#
# File /usr/lib/python3.12/multiprocessing/popen_fork.py:27, in Popen.poll(self, flag)
#      25 if self.returncode is None:
#      26     try:
# ---> 27         pid, sts = os.waitpid(self.pid, flag)
#      28     except OSError:
#      29         # Child process not yet created. See #1731717
#      30         # e.errno == errno.ECHILD == 10
#      31         return None
#
# KeyboardInterrupt:

# %% [markdown]
# Итак, в отличие от, надеемся, успешного завершения маршрута в модуле 2, сейчас ваша машинка ведёт себя совсем иначе. Например, она внезапно едет в совершенно другую сторону (это особенно хорошо видно при использовании СУПА).
# И это ещё не всё, что может пойти не так..
#
# В этой реализации не очень много кода, теоретически, вы можете его весь изучить и устранить "незадокументированные возможности", однако в реальных системах кода гораздо больше. Например, кодовая база проекта с открытым исходным кодом ArduPilot, реализующего в том числе логику автопилота, составляет примерно миллион строк.
#
# Сколько времени вам понадобится, чтобы изучить и протестировать миллион строк кода? А ведь придётся проводить анализ и каждого обновления.. При этом неприятности могут быть хорошо спрятанными и на первый взгляд безобидными, вряд ли злоумышленники облегчат задачу и назовут свои изменения, например, "hacking_the_system" или "allowing_secret_remote_access". Вредоносный код может выглядеть совершенно безобидно или маскироваться под программный дефект.
#
# Поэтому тщательный анализ потребует большого количества ресурсов (человеческих, вычислительных, временных), что стоит дорого.
#
# Логичным выходом является выделение критичных для целей безопасности проверок в отдельный блок, который протестировать должно быть гораздо проще.

# %% [markdown]
# #### Задания
#
# В этом модуле задание будет состоять из двух частей разной сложности:
#
# **3.1. добавить новый блок - "Ограничитель"** - этот модуль должен будет обеспечить соблюдение ограничений, указанных в маршрутном задании - это необходимо для обеспечения ЦБ1
#
# **З.2. *(задание повышенной сложности)* добавить монитор безопасности (МБ)** - он должен контролировать все взаимодействия *бортовых систем* (т.е. не включая планировщик и симулятор) и не давать блокам взаимодействовать друг с другом непредусмотренным образом - например, блок №5 может принимать команды только от №3, попытка передать команду в №5 от №2 должна блокироваться нашим монитором безопасности - потенциально это необходимо для обеспечения всех ЦБ

# %% [markdown]
# Для выполнения первой части задачи 3.1. необходимо для начала изменить архитектуру АНТС как показано на рис. 5
#
# ![Архитектура системы с ограничителем](images/ciac-arch-m31.png)
#
# Рис. 5. Архитектура АНТС с ограничителем (для ЦБ1)

# %% [markdown]
# Код базового класса Ограничителя находится в файле src/safety_block.py
#
# По аналогии с заданием в модуле 1, необходимо создать на основе этого класса свой собственный под названием SafetyBlock, в котором реализовать передачу команд в приводы движения, только перед эти необходимо ещё и проконтролировать их безопасность.
#
# Также необходимо реализовать передачу маршрутного задания из CommunicationGateway в SafetyBlock и координат из модуля Navigation в соответствии со стрелками на рис.5 выше.
#
# Если всё сделано правильно, то Ограничителю будет известно следующее
#
# - _mission - текущее маршрутное задание
# - _position - текущие координаты
#
# После проверки нужно установить значение внутренних переменных
# - _speed - текущая (допустимая) скорость
# - _direction - текущее (допустимое) направление
#
# Желательно завершить следование по маршруту. В критической ситуации, если продолжение маршрута невозможно, следует установить значение скорости и направления в 0, после чего передать эти команды в блок приводов (Servos)

# %% [markdown]
# Базовый сценарий для новой архитектуры можно представить следующим образом (см. рис. 6)
#
# ![Базовый сценарий с блоком безопасности](images/basic-scenario-with-safety-block1.png)
#
# Рис. 6. Базовый сценарий с блоком безопасности

# %% [markdown]
# Заготовка кода SafetyBlock
#
# ```python
# class SafetyBlock(BaseSafetyBlock):
#     """ класс ограничений безопасности """
#
#     def _set_new_direction(self, direction: float):
#         """ установка нового направления перемещения """
#         self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
#         self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
#         self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
#         # TODO реализовать контроль безопасности изменения направления
#         self._direction = direction
#         self._send_direction_to_consumers()
#
#     def _set_new_speed(self, speed: float):
#         """ установка новой скорости """
#         # TODO реализовать контроль безопасности изменения скорости
#         self._speed = speed
#         self._send_speed_to_consumers()
#
#
#     def _send_speed_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем скорость получателям")
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_speed",
#                             parameters=self._speed
#                             )
#         servos_q.put(event_speed)
#
#     def _send_direction_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем направление получателям")
#
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_direction",
#                             parameters=self._direction
#                             )
#         servos_q.put(event_speed)
# ```

# %%
from src.safety_block import BaseSafetyBlock
from src.config import *
import math
from time import sleep
from geopy import Point as GeoPoint
from src.config import LOG_ERROR, LOG_INFO, LOG_DEBUG
from multiprocessing import Queue
from src.config import SERVOS_QUEUE_NAME
from src.event_types import Event


class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        # TODO реализовать контроль безопасности изменения направления

        if not self._position or not self._route:
            self._log_message(LOG_ERROR, f"не получилось установить новое направление - неизвестный маршрут или позиция машинки")
            return
        
        current = self._position
        next = self._route.next_point()
        
        if not next:
            self._log_message(LOG_ERROR, f"не получилось установить новое направление - достигнут конец маршрута")
            return
        
        bearing = self._calculate_bearing(current, next)
        
        new_direction = max(bearing - 5, min(bearing + 5, direction))
        
        if new_direction != direction:
            self._log_message(LOG_ERROR, f"попытка изменить направление движения не в ту сторону: {direction}. Скорректировано на {new_direction}")
                
        self._direction = new_direction
        # отправка сообщения с желаемым направлением
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        if not self._route:
            self._log_message(LOG_ERROR, f"не получилось установить новую скорость - неизвестный маршрут")
            return

        new_speed = max(0, min(speed, self._route.calculate_speed()))
        if new_speed != speed:
            self._log_message(LOG_ERROR, f"попытка изменить скорость движения на запрещенную: {speed}. Скорректировано на {new_speed}")
                
        self._speed = new_speed
        self._send_speed_to_consumers()

    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        servos_q.put(event_speed)

    def _lock_cargo(self, _):
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._send_lock_cargo_to_consumers()

    def _send_lock_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду блокировки в CargoBay")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="lock_cargo",
            parameters=None
        )
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        cargo_q.put(event)
        
    def _release_cargo(self, _):
        if not self._route or not self._route.route_finished:
            self._log_message(LOG_DEBUG, "Не разрешили открыть груз тк не на маршруте или не закончили его")
            return
        self._send_release_cargo_to_consumers()

    def _send_release_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду выгрузки в CargoBay")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="release_cargo",
            parameters=None
        )
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        cargo_q.put(event)

    def _calculate_bearing(self, start: GeoPoint, end: GeoPoint):
        delta_longitude = end.longitude - start.longitude
        x = math.sin(math.radians(delta_longitude)) * \
            math.cos(math.radians(end.latitude))
        y = math.cos(math.radians(start.latitude)) * math.sin(math.radians(end.latitude)) - \
            math.sin(math.radians(start.latitude)) * math.cos(math.radians(end.latitude)) * \
            math.cos(math.radians(delta_longitude))
        initial_bearing_rad = math.atan2(x, y)

        # Преобразуем радианы в градусы
        initial_bearing_deg = math.degrees(initial_bearing_rad)

        # Нормализуем значение в диапазоне [0, 360]
        compass_bearing = (initial_bearing_deg + 360) % 360

        return compass_bearing

# %%
# 2. напишите в этом блоке реализацию изменённых блоков связи, управления и навигации, 
# чтобы передавать данные согласно изменённой архитектуре на рис. 5 для обеспечения работы по сценарию на рис.6

# вставьте сюда ваш код
from src.control_system import BaseControlSystem
from src.navigation_system import BaseNavigationSystem
from src.communication_gateway import BaseCommunicationGateway
from multiprocessing import Queue
from src.config import SAFETY_BLOCK_QUEUE_NAME
from src.config import SERVOS_QUEUE_NAME
from src.config import CONTROL_SYSTEM_QUEUE_NAME
from src.event_types import Event


class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_speed", parameters=speed
                    ) # замените на код создания сообщения со скоростью для приводов
                           # подсказка, требуемая операция - set_speed

        # отправка сообщения с желаемым направлением
        event_direction = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_direction", parameters=direction
                    ) # замените на код создания сообщения с направлением для приводов
                               # подсказка, требуемая операция - set_direction

        safety_q.put(event_speed)
        safety_q.put(event_direction)  
        
    def _lock_cargo(self):
        """ заблокировать грузовой отсек """
        safety_q = self._queues_dir.get_queue(SAFETY_BLOCK_QUEUE_NAME)
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                    destination=SAFETY_BLOCK_QUEUE_NAME,
                    operation="lock_cargo", parameters= None
                    )
        safety_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """
        safety_q = self._queues_dir.get_queue(SAFETY_BLOCK_QUEUE_NAME)
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME, 
                    destination=SAFETY_BLOCK_QUEUE_NAME,
                    operation="release_cargo", parameters= None
                    )  
        safety_q.put(event)      


class CommunicationGateway(BaseCommunicationGateway):
    """CommunicationGateway класс для реализации логики взаимодействия
    с системой планирования заданий

    Работает в отдельном процессе, поэтому создаётся как наследник класса Process
    """
    def _send_mission_to_consumers(self):
        """ метод для отправки сообщения с маршрутным заданием в систему управления """
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)
                
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)


class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):        
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="position_update", parameters=self._position
                      )
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)
      
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        event =  Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="position_update", parameters=self._position
                    ) # замените на код создания сообщения с координатами для системы управления 
                     # подсказка, требуемая операция - position_update
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)

# %%
# создадим все остальные компоненты

# используем то же маршрутное задание, которое было в модуле 2
from time import sleep
from geopy import Point as GeoPoint


from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser


# возьмём маршрут из модуля 2
wpl_file = "module_2.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()
print(points)

from src.mission_type import GeoSpecificSpeedLimit
speed_limits = [
    GeoSpecificSpeedLimit(0, 20),
    GeoSpecificSpeedLimit(3, 50),
    GeoSpecificSpeedLimit(6, 20),
    GeoSpecificSpeedLimit(8, 50),
    GeoSpecificSpeedLimit(9, 20),
]


home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
################################

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)


system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ])

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(210)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [Point(59.8815191, 29.8300481, 0.0), Point(59.8819121, 29.8282993, 0.0), Point(59.8818098, 29.8277092, 0.0), Point(59.8818583, 29.8274088, 0.0), Point(59.8810884, 29.8267436, 0.0), Point(59.8796617, 29.8254454, 0.0), Point(59.8785849, 29.8245013, 0.0), Point(59.8781972, 29.8241472, 0.0), Point(59.8781003, 29.8241258, 0.0), Point(59.8780249, 29.8242867, 0.0), Point(59.8774811, 29.8267651, 0.0), Point(59.8769158, 29.8291469, 0.0), Point(59.8768512, 29.8291361, 0.0), Point(59.8765389, 29.8288143, 0.0), Point(59.8761512, 29.8284817, 0.0), Point(59.8756531, 29.8274866, 0.0), Point(59.8752903, 29.8277186, 0.0), Point(59.8751927, 29.8276126, 0.0), Point(59.875042, 29.8278809, 0.0), Point(59.8751443, 29.8284495, 0.0), Point(59.8751335, 29.8289645, 0.0), Point(59.8749935, 29.8295438, 0.0), Point(59.8747674, 29.829855, 0.0), Point(59.874455, 29.8299837, 0.0), Point(59.8742666, 29.8298872, 0.0)]
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][SAFETY] старт ограничителя
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 16:28:35.872607
# [ИНФО][SAFETY] Блокировка грузового отсека
# [ИНФО][CONTROL] новая скорость 20 (была 0)
# [ИНФО][CONTROL] новое направление 294 (было 0)
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4688s N, 29 49m 48.1732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4688s N, 29 49m 48.1732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4688s N, 29 49m 48.1732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4688s N, 29 49m 48.1732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.5054s N, 29 49m 48.0102s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.5421s N, 29 49m 47.8472s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.5715s N, 29 49m 47.7168s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.6082s N, 29 49m 47.5539s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.6449s N, 29 49m 47.3909s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.6815s N, 29 49m 47.2279s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7182s N, 29 49m 47.0649s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7549s N, 29 49m 46.9019s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7916s N, 29 49m 46.739s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.8283s N, 29 49m 46.576s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.8649s N, 29 49m 46.413s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.9016s N, 29 49m 46.25s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.9383s N, 29 49m 46.087s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.975s N, 29 49m 45.924s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.0116s N, 29 49m 45.761s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.0483s N, 29 49m 45.598s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.0849s N, 29 49m 45.435s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1216s N, 29 49m 45.272s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1583s N, 29 49m 45.109s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1949s N, 29 49m 44.946s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.2316s N, 29 49m 44.783s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.2682s N, 29 49m 44.62s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3049s N, 29 49m 44.457s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3415s N, 29 49m 44.294s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3782s N, 29 49m 44.1309s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4148s N, 29 49m 43.9679s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4514s N, 29 49m 43.8049s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.488s N, 29 49m 43.6419s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5247s N, 29 49m 43.4788s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5613s N, 29 49m 43.3158s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5979s N, 29 49m 43.1527s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6345s N, 29 49m 42.9897s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6711s N, 29 49m 42.8266s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7077s N, 29 49m 42.6636s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7443s N, 29 49m 42.5005s E
# [ИНФО][CONTROL] новое направление 293 (было 294)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7808s N, 29 49m 42.3374s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8101s N, 29 49m 42.2069s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 73 (было 293)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8466s N, 29 49m 42.0438s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 73.92074430984945. Скорректировано на 248.92074430984945
# [ИНФО][CONTROL] новое направление 70 (было 73)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8831s N, 29 49m 41.8807s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 70.98928893975358. Скорректировано на 245.98928893975358
# [ИНФО][CONTROL] новое направление 67 (было 70)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.9196s N, 29 49m 41.7175s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 67.6991654976357. Скорректировано на 242.6991654976357
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8873s N, 29 49m 41.5509s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 67.58992502455226. Скорректировано на 242.58992502455223
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8508s N, 29 49m 41.3877s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 67.75540913643454. Скорректировано на 242.75540913643454
# [ИНФО][CONTROL] новое направление 68 (было 67)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8096s N, 29 49m 41.2291s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 68.3277941823946. Скорректировано на 243.3277941823946
# [ИНФО][CONTROL] новое направление 69 (было 68)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7683s N, 29 49m 41.0705s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 69.05821382273672. Скорректировано на 244.05821382273672
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7272s N, 29 49m 40.9118s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 69.97507075252372. Скорректировано на 244.97507075252372
# [ИНФО][CONTROL] новое направление 71 (было 69)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6869s N, 29 49m 40.7522s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 71.10361295550399. Скорректировано на 246.103612955504
# [ИНФО][CONTROL] новое направление 72 (было 71)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6476s N, 29 49m 40.5916s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 72.53961534732173. Скорректировано на 247.53961534732173
# [ИНФО][CONTROL] новое направление 74 (было 72)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6097s N, 29 49m 40.4298s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 74.46767509316078. Скорректировано на 249.4676750931608
# [ИНФО][CONTROL] новое направление 77 (было 74)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5733s N, 29 49m 40.2665s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 77.30967772586843. Скорректировано на 252.30967772586843
# [ИНФО][CONTROL] новое направление 82 (было 77)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.539s N, 29 49m 40.1015s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 82.27259071534252. Скорректировано на 257.2725907153425
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 120 (была 20)
# [ИНФО][CONTROL] новое направление 286 (было 82)
# [ИНФО][SAFETY] сегмент пройден
# [ОШИБКА][SAFETY] попытка изменить скорость движения на запрещенную: 120. Скорректировано на 20
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5075s N, 29 49m 39.9343s E
# [ИНФО][CONTROL] новое направление 290 (было 286)
# [ОШИБКА][SAFETY] попытка изменить скорость движения на запрещенную: 120. Скорректировано на 20
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4802s N, 29 49m 39.7641s E
# [ИНФО][CONTROL] новое направление 296 (было 290)
# [ОШИБКА][SAFETY] попытка изменить скорость движения на запрещенную: 120. Скорректировано на 20
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4605s N, 29 49m 39.59s E
# [ИНФО][CONTROL] новое направление 298 (было 296)
# [ОШИБКА][SAFETY] попытка изменить скорость движения на запрещенную: 120. Скорректировано на 20
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4853s N, 29 49m 39.4184s E
# [ИНФО][CONTROL] новое направление 300 (было 298)
# [ОШИБКА][SAFETY] попытка изменить скорость движения на запрещенную: 120. Скорректировано на 20
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5174s N, 29 49m 39.2516s E
# [ИНФО][CONTROL] новое направление 302 (было 300)
# [ОШИБКА][SAFETY] попытка изменить скорость движения на запрещенную: 120. Скорректировано на 20
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5574s N, 29 49m 39.0917s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 50 (была 120)
# [ИНФО][CONTROL] новое направление 206 (было 302)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6004s N, 29 49m 38.935s E
# [ИНФО][CONTROL] новое направление 204 (было 206)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6462s N, 29 49m 38.7814s E
# [ИНФО][CONTROL] новое направление 203 (было 204)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6939s N, 29 49m 38.6302s E
# [ИНФО][CONTROL] новое направление 202 (было 203)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.493s N, 29 49m 38.4314s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.2892s N, 29 49m 38.2446s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.0827s N, 29 49m 38.0698s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.8758s N, 29 49m 37.897s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.6687s N, 29 49m 37.7254s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4615s N, 29 49m 37.554s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.2542s N, 29 49m 37.3828s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.047s N, 29 49m 37.2116s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.8397s N, 29 49m 37.0404s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.6325s N, 29 49m 36.8692s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.4253s N, 29 49m 36.6979s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.2181s N, 29 49m 36.5266s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 204 (было 202)
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.0523s N, 29 49m 36.3895s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.8451s N, 29 49m 36.218s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.638s N, 29 49m 36.0463s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.4309s N, 29 49m 35.8742s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.2267s N, 29 49m 35.6891s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.0227s N, 29 49m 35.5034s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.8187s N, 29 49m 35.3171s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.615s N, 29 49m 35.1302s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.4112s N, 29 49m 34.9432s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.2075s N, 29 49m 34.7562s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.0037s N, 29 49m 34.5691s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.8s N, 29 49m 34.3819s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.5963s N, 29 49m 34.1947s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.3926s N, 29 49m 34.0075s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.1889s N, 29 49m 33.8203s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.9852s N, 29 49m 33.633s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.7815s N, 29 49m 33.4457s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.5778s N, 29 49m 33.2584s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.3741s N, 29 49m 33.0711s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.1704s N, 29 49m 32.8837s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.9668s N, 29 49m 32.6964s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.7631s N, 29 49m 32.5089s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.5595s N, 29 49m 32.3214s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.3558s N, 29 49m 32.1339s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.1522s N, 29 49m 31.9463s E
# [ИНФО][CONTROL] новое направление 205 (было 204)
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.9486s N, 29 49m 31.7585s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 203 (было 205)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.7451s N, 29 49m 31.5706s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.5416s N, 29 49m 31.3825s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.3379s N, 29 49m 31.1953s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.1325s N, 29 49m 31.0156s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.9269s N, 29 49m 30.8364s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.7213s N, 29 49m 30.6576s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.5157s N, 29 49m 30.4788s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.3512s N, 29 49m 30.3357s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.1456s N, 29 49m 30.1569s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.94s N, 29 49m 29.9781s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.7344s N, 29 49m 29.7992s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.5288s N, 29 49m 29.6203s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.3233s N, 29 49m 29.4414s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.1177s N, 29 49m 29.2625s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.9121s N, 29 49m 29.0835s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.7065s N, 29 49m 28.9045s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.501s N, 29 49m 28.7254s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.2955s N, 29 49m 28.5462s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.09s N, 29 49m 28.367s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 50)
# [ИНФО][CONTROL] новое направление 204 (было 203)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.8845s N, 29 49m 28.1876s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.6791s N, 29 49m 28.0079s E
# [ИНФО][CONTROL] новое направление 205 (было 204)
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.4738s N, 29 49m 27.8275s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.3922s N, 29 49m 27.753s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.3108s N, 29 49m 27.678s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.2295s N, 29 49m 27.6024s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.1482s N, 29 49m 27.5267s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.0669s N, 29 49m 27.4509s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.9856s N, 29 49m 27.3751s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.9044s N, 29 49m 27.2992s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.8231s N, 29 49m 27.2234s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.7419s N, 29 49m 27.1475s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.6606s N, 29 49m 27.0715s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 189 (было 205)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.5794s N, 29 49m 26.9956s E
# [ИНФО][CONTROL] новое направление 185 (было 189)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.4982s N, 29 49m 26.9195s E
# [ИНФО][CONTROL] новое направление 179 (было 185)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.4156s N, 29 49m 26.8526s E
# [ИНФО][CONTROL] новое направление 175 (было 179)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.3269s N, 29 49m 26.825s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 40 (была 20)
# [ИНФО][CONTROL] новое направление 138 (было 175)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.2375s N, 29 49m 26.8109s E
# [ИНФО][CONTROL] новое направление 129 (было 138)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.1478s N, 29 49m 26.814s E
# [ИНФО][CONTROL] новое направление 119 (было 129)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.0495s N, 29 49m 26.8737s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 40)
# [ИНФО][CONTROL] новое направление 113 (было 119)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.9196s N, 29 49m 27.1192s E
# [ИНФО][CONTROL] новое направление 112 (было 113)
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.81s N, 29 49m 27.4008s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.7317s N, 29 49m 27.6818s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.6965s N, 29 49m 27.846s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.6688s N, 29 49m 27.9778s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.6345s N, 29 49m 28.1428s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.6002s N, 29 49m 28.3079s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.5659s N, 29 49m 28.4729s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.5317s N, 29 49m 28.6379s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.4974s N, 29 49m 28.8029s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.4631s N, 29 49m 28.968s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.4289s N, 29 49m 29.133s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.3946s N, 29 49m 29.298s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.3603s N, 29 49m 29.4631s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.3261s N, 29 49m 29.6281s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.2918s N, 29 49m 29.7931s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.2575s N, 29 49m 29.9582s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.2233s N, 29 49m 30.1232s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.189s N, 29 49m 30.2882s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.1548s N, 29 49m 30.4533s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.1205s N, 29 49m 30.6183s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.0862s N, 29 49m 30.7833s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.052s N, 29 49m 30.9484s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.0177s N, 29 49m 31.1134s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.9835s N, 29 49m 31.2784s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.9492s N, 29 49m 31.4435s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.915s N, 29 49m 31.6085s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.8807s N, 29 49m 31.7736s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.8465s N, 29 49m 31.9386s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.8122s N, 29 49m 32.1037s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.778s N, 29 49m 32.2687s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.7438s N, 29 49m 32.4338s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.7095s N, 29 49m 32.5988s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.6753s N, 29 49m 32.7639s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.641s N, 29 49m 32.9289s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.6068s N, 29 49m 33.094s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.5726s N, 29 49m 33.259s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.5383s N, 29 49m 33.4241s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.511s N, 29 49m 33.5562s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.4767s N, 29 49m 33.7212s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.4425s N, 29 49m 33.8863s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.4083s N, 29 49m 34.0514s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.3741s N, 29 49m 34.2164s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.3399s N, 29 49m 34.3815s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.3057s N, 29 49m 34.5466s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2715s N, 29 49m 34.7117s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2373s N, 29 49m 34.8767s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2031s N, 29 49m 35.0418s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.1689s N, 29 49m 35.2069s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.1347s N, 29 49m 35.372s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.1006s N, 29 49m 35.5372s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.0664s N, 29 49m 35.7023s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.0323s N, 29 49m 35.8674s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.9981s N, 29 49m 36.0325s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 115 (было 112)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.964s N, 29 49m 36.1977s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.9299s N, 29 49m 36.3629s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.8959s N, 29 49m 36.5281s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.8576s N, 29 49m 36.6896s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.8192s N, 29 49m 36.851s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7808s N, 29 49m 37.0123s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7423s N, 29 49m 37.1737s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7039s N, 29 49m 37.335s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.6654s N, 29 49m 37.4963s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.627s N, 29 49m 37.6577s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.5885s N, 29 49m 37.819s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.5501s N, 29 49m 37.9803s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.5116s N, 29 49m 38.1417s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4732s N, 29 49m 38.303s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4347s N, 29 49m 38.4643s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.3963s N, 29 49m 38.6257s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.3578s N, 29 49m 38.787s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.3194s N, 29 49m 38.9484s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.2809s N, 29 49m 39.1097s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.2425s N, 29 49m 39.2711s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.204s N, 29 49m 39.4324s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.1733s N, 29 49m 39.5615s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.1349s N, 29 49m 39.7228s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.0964s N, 29 49m 39.8842s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.058s N, 29 49m 40.0455s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.0195s N, 29 49m 40.2069s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9811s N, 29 49m 40.3683s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9427s N, 29 49m 40.5296s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9043s N, 29 49m 40.691s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.8658s N, 29 49m 40.8523s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.8274s N, 29 49m 41.0137s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.789s N, 29 49m 41.1751s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.7506s N, 29 49m 41.3364s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.7121s N, 29 49m 41.4978s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.6737s N, 29 49m 41.6592s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.6353s N, 29 49m 41.8205s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.5969s N, 29 49m 41.9819s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.5585s N, 29 49m 42.1433s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.5201s N, 29 49m 42.3047s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.4817s N, 29 49m 42.4661s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.4433s N, 29 49m 42.6275s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.4049s N, 29 49m 42.7888s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.3665s N, 29 49m 42.9502s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.3281s N, 29 49m 43.1116s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.2898s N, 29 49m 43.273s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.2514s N, 29 49m 43.4344s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.213s N, 29 49m 43.5959s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.1746s N, 29 49m 43.7573s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.1363s N, 29 49m 43.9187s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.0979s N, 29 49m 44.0801s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.0596s N, 29 49m 44.2416s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.0213s N, 29 49m 44.403s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.983s N, 29 49m 44.5645s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 163 (было 115)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.9447s N, 29 49m 44.726s E
# [ИНФО][CONTROL] новое направление 176 (было 163)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.9141s N, 29 49m 44.8552s E
# [ИНФО][CONTROL] новое направление 196 (было 176)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.8758s N, 29 49m 45.0167s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 208 (было 196)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.7897s N, 29 49m 45.067s E
# [ИНФО][CONTROL] новое направление 210 (было 208)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.7002s N, 29 49m 45.0795s E
# [ИНФО][CONTROL] новое направление 211 (было 210)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.6142s N, 29 49m 45.028s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.5351s N, 29 49m 44.9436s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.4576s N, 29 49m 44.8537s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.3808s N, 29 49m 44.7612s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.3042s N, 29 49m 44.6681s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.2277s N, 29 49m 44.5747s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.1512s N, 29 49m 44.4812s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.0748s N, 29 49m 44.3876s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.9983s N, 29 49m 44.294s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.9219s N, 29 49m 44.2004s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.8455s N, 29 49m 44.1068s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.7691s N, 29 49m 44.0132s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.6926s N, 29 49m 43.9195s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 203 (было 211)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.6163s N, 29 49m 43.8258s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.5399s N, 29 49m 43.732s E
# [ИНФО][CONTROL] новое направление 202 (было 203)
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.4635s N, 29 49m 43.6381s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.3814s N, 29 49m 43.5661s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.2989s N, 29 49m 43.4955s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.2162s N, 29 49m 43.4264s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.1334s N, 29 49m 43.3574s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.0506s N, 29 49m 43.2884s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.9678s N, 29 49m 43.2196s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.885s N, 29 49m 43.1508s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.8021s N, 29 49m 43.082s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.7193s N, 29 49m 43.0131s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.6365s N, 29 49m 42.9443s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.5537s N, 29 49m 42.8755s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.4709s N, 29 49m 42.8066s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.3881s N, 29 49m 42.7377s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.3052s N, 29 49m 42.6688s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 224 (было 202)
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.239s N, 29 49m 42.6137s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.1562s N, 29 49m 42.5447s E
# [ИНФО][CONTROL] новое направление 225 (было 224)
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.0734s N, 29 49m 42.4757s E
# [ИНФО][CONTROL] новое направление 226 (было 225)
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.9907s N, 29 49m 42.4065s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.9272s N, 29 49m 42.2803s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.8646s N, 29 49m 42.1524s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.8029s N, 29 49m 42.0227s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.7413s N, 29 49m 41.8928s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.6798s N, 29 49m 41.7629s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.6182s N, 29 49m 41.6329s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.5567s N, 29 49m 41.5029s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.4951s N, 29 49m 41.373s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.4336s N, 29 49m 41.243s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.3721s N, 29 49m 41.113s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.3105s N, 29 49m 40.983s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.249s N, 29 49m 40.853s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.1875s N, 29 49m 40.723s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.126s N, 29 49m 40.5929s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.0645s N, 29 49m 40.4629s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.003s N, 29 49m 40.3329s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.9415s N, 29 49m 40.2028s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.88s N, 29 49m 40.0728s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.8185s N, 29 49m 39.9427s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.757s N, 29 49m 39.8126s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.6955s N, 29 49m 39.6825s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.6341s N, 29 49m 39.5524s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.5726s N, 29 49m 39.4223s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.5112s N, 29 49m 39.2921s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 167 (было 226)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.4497s N, 29 49m 39.1619s E
# [ИНФО][CONTROL] новое направление 164 (было 167)
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.3884s N, 29 49m 39.0317s E
# [ИНФО][CONTROL] новое направление 161 (было 164)
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.3217s N, 29 49m 38.9352s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.2344s N, 29 49m 38.9761s E
# [ИНФО][CONTROL] новое направление 160 (было 161)
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.1483s N, 29 49m 39.0262s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.0632s N, 29 49m 39.0831s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.9783s N, 29 49m 39.141s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.8935s N, 29 49m 39.1995s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.8087s N, 29 49m 39.258s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.7239s N, 29 49m 39.3166s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.6391s N, 29 49m 39.3752s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.5543s N, 29 49m 39.4338s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.4695s N, 29 49m 39.4925s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.4017s N, 29 49m 39.5394s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.3169s N, 29 49m 39.5981s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.2322s N, 29 49m 39.6568s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 198 (было 160)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.1474s N, 29 49m 39.7155s E
# [ИНФО][CONTROL] новое направление 206 (было 198)
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.0627s N, 29 49m 39.7743s E
# [ИНФО][CONTROL] новое направление 217 (было 206)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.9779s N, 29 49m 39.8332s E
# [ИНФО][CONTROL] новое направление 222 (было 217)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.893s N, 29 49m 39.7752s E
# [ИНФО][CONTROL] новое направление 230 (было 222)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.8128s N, 29 49m 39.6951s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 146 (было 230)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.7412s N, 29 49m 39.5875s E
# [ИНФО][CONTROL] новое направление 139 (было 146)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.6755s N, 29 49m 39.4658s E
# [ИНФО][CONTROL] новое направление 131 (было 139)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.6186s N, 29 49m 39.3277s E
# [ИНФО][CONTROL] новое направление 129 (было 131)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.544s N, 29 49m 39.4267s E
# [ИНФО][CONTROL] новое направление 128 (было 129)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4761s N, 29 49m 39.5437s E
# [ИНФО][CONTROL] новое направление 127 (было 128)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4164s N, 29 49m 39.6769s E
# [ИНФО][CONTROL] новое направление 126 (было 127)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3591s N, 29 49m 39.8143s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3038s N, 29 49m 39.955s E
# [ИНФО][CONTROL] новое направление 125 (было 126)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2494s N, 29 49m 40.097s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 73 (было 125)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1959s N, 29 49m 40.2403s E
# [ИНФО][CONTROL] новое направление 69 (было 73)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1429s N, 29 49m 40.3845s E
# [ИНФО][CONTROL] новое направление 65 (было 69)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.0908s N, 29 49m 40.5298s E
# [ИНФО][CONTROL] новое направление 64 (было 65)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1163s N, 29 49m 40.701s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1473s N, 29 49m 40.8685s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1843s N, 29 49m 41.0312s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2224s N, 29 49m 41.1929s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2611s N, 29 49m 41.3539s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3s N, 29 49m 41.5148s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3391s N, 29 49m 41.6756s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3782s N, 29 49m 41.8363s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4173s N, 29 49m 41.997s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 88 (было 64)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4564s N, 29 49m 42.1577s E
# [ИНФО][CONTROL] новое направление 90 (было 88)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4955s N, 29 49m 42.3184s E
# [ИНФО][CONTROL] новое направление 92 (было 90)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5271s N, 29 49m 42.4827s E
# [ИНФО][CONTROL] новое направление 93 (было 92)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5285s N, 29 49m 42.6612s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5265s N, 29 49m 42.8397s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5217s N, 29 49m 43.018s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5163s N, 29 49m 43.1962s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5106s N, 29 49m 43.3743s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5047s N, 29 49m 43.5525s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4988s N, 29 49m 43.7307s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4928s N, 29 49m 43.9088s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 113 (было 93)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.488s N, 29 49m 44.0513s E
# [ИНФО][CONTROL] новое направление 115 (было 113)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.482s N, 29 49m 44.2295s E
# [ИНФО][CONTROL] новое направление 117 (было 115)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.476s N, 29 49m 44.4076s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4398s N, 29 49m 44.5709s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4014s N, 29 49m 44.7323s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3606s N, 29 49m 44.8913s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3194s N, 29 49m 45.0499s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2779s N, 29 49m 45.2083s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2364s N, 29 49m 45.3666s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1949s N, 29 49m 45.5248s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1533s N, 29 49m 45.6831s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1117s N, 29 49m 45.8413s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.0702s N, 29 49m 45.9996s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 142 (было 117)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.0287s N, 29 49m 46.1579s E
# [ИНФО][CONTROL] новое направление 144 (было 142)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.9871s N, 29 49m 46.3161s E
# [ИНФО][CONTROL] новое направление 147 (было 144)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.9456s N, 29 49m 46.4744s E
# [ИНФО][CONTROL] новое направление 150 (было 147)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.9042s N, 29 49m 46.6328s E
# [ИНФО][CONTROL] новое направление 151 (было 150)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.8329s N, 29 49m 46.7413s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.7596s N, 29 49m 46.8444s E
# [ИНФО][CONTROL] новое направление 152 (было 151)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.6841s N, 29 49m 46.941s E
# [ИНФО][CONTROL] новое направление 153 (было 152)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.6062s N, 29 49m 47.0296s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.5276s N, 29 49m 47.1159s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.4484s N, 29 49m 47.1998s E
# [ИНФО][CONTROL] новое направление 154 (было 153)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.3686s N, 29 49m 47.2818s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 166 (было 154)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.2886s N, 29 49m 47.3626s E
# [ИНФО][CONTROL] новое направление 167 (было 166)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.2082s N, 29 49m 47.4422s E
# [ИНФО][CONTROL] новое направление 169 (было 167)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.1275s N, 29 49m 47.5203s E
# [ИНФО][CONTROL] новое направление 170 (было 169)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.0453s N, 29 49m 47.5899s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.9578s N, 29 49m 47.6297s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.8699s N, 29 49m 47.6664s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.7818s N, 29 49m 47.6998s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.6933s N, 29 49m 47.7304s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.6048s N, 29 49m 47.7601s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.5162s N, 29 49m 47.7888s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.4276s N, 29 49m 47.8172s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.339s N, 29 49m 47.8455s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.2681s N, 29 49m 47.8681s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 190 (было 170)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.1794s N, 29 49m 47.8962s E
# [ИНФО][CONTROL] новое направление 192 (было 190)
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.0908s N, 29 49m 47.9244s E
# [ИНФО][CONTROL] новое направление 195 (было 192)
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.0022s N, 29 49m 47.9526s E
# [ИНФО][CONTROL] новое направление 196 (было 195)
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.9139s N, 29 49m 47.9201s E
# [ИНФО][CONTROL] новое направление 197 (было 196)
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.8264s N, 29 49m 47.8806s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.74s N, 29 49m 47.8324s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.6539s N, 29 49m 47.7818s E
# [ИНФО][CONTROL] новое направление 198 (было 197)
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.5681s N, 29 49m 47.7292s E
# [ИНФО][CONTROL] маршрут пройден, текущее время 16:32:05.979025
# [ИНФО][CONTROL] новая скорость 0.0 (была 20)
# [ИНФО][CONTROL] новое направление 0 (было 198)
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.4825s N, 29 49m 47.6756s E
# [ОШИБКА][SAFETY] не получилось установить новое направление - достигнут конец маршрута
# [ИНФО][CARGO] выгрузка
# [ИНФО][CARGO] груз оставлен
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# #### Обеспечение ЦБ3: контроль доставки груза
#
# С помощью логики ограничителя выше мы реализовали обеспечение ЦБ1 (соблюдение заданных ограничений), однако есть ещё ЦБ3 (отгрузка только в заданной точке), не говоря о ЦБ2 (следование только по аутентичному маршруту).
#
# Для обеспечения ЦБ3 необходимо сделать следующее
# 1. изменить последовательность передачи команд, чтобы в блок управления грузовым отсеком (CargoBay) команды приходили только после проверки в Ограничителе
# 2. доработайте реализацию Ограничителя, чтобы команда на выгрузку передавалась в CargoBay только в конечной точке маршрута
# 3. продумайте логику работы блока безопасности, если система управления полностью перестанет работать (т.е. перестанет отправлять новые команды).
#
# Изменённая архитектура приведена на рис. 7.
#
# ![Ограничитель для обеспечения ЦБ1 и ЦБ3](images/ciac-arch-m312.png)
#
# Рис. 7. Ограничитель для обеспечения ЦБ1 и ЦБ3

# %%
# напишите свой код в этой ячейке, запустите машинку по маршруту, убедитесь, 
# что в конечной (и только в конечной!) точке CargoBay получает команду и успешно выполняет выгрузку

from src.safety_block import BaseSafetyBlock
from src.config import *
import math
from time import sleep
from geopy import Point as GeoPoint
from src.config import LOG_ERROR, LOG_INFO, LOG_DEBUG
from multiprocessing import Queue
from src.config import SERVOS_QUEUE_NAME
from src.event_types import Event


class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        # TODO реализовать контроль безопасности изменения направления

        if not self._position or not self._route:
            self._log_message(LOG_ERROR, f"не получилось установить новое направление - неизвестный маршрут или позиция машинки")
            return
        
        current = self._position
        next = self._route.next_point()
        
        if not next:
            self._log_message(LOG_ERROR, f"не получилось установить новое направление - достигнут конец маршрута")
            return
        
        bearing = self._calculate_bearing(current, next)
        
        new_direction = max(bearing - 5, min(bearing + 5, direction))
        
        if new_direction != direction:
            self._log_message(LOG_ERROR, f"попытка изменить направление движения не в ту сторону: {direction}. Скорректировано на {new_direction}")
                
        self._direction = new_direction
        # отправка сообщения с желаемым направлением
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        if not self._route:
            self._log_message(LOG_ERROR, f"не получилось установить новую скорость - неизвестный маршрут")
            return

        new_speed = max(0, min(speed, self._route.calculate_speed()))
        if new_speed != speed:
            self._log_message(LOG_ERROR, f"попытка изменить скорость движения на запрещенную: {speed}. Скорректировано на {new_speed}")
                
        self._speed = new_speed
        self._send_speed_to_consumers()

    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        servos_q.put(event_speed)

    def _lock_cargo(self, _):
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._send_lock_cargo_to_consumers()

    def _send_lock_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду блокировки в CargoBay")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="lock_cargo",
            parameters=None
        )
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        cargo_q.put(event)
        
    def _release_cargo(self, _):
        if not self._route or not self._route.route_finished:
            self._log_message(LOG_DEBUG, "Не разрешили открыть груз тк не на маршруте или не закончили его")
            return
        self._send_release_cargo_to_consumers()

    def _send_release_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду выгрузки в CargoBay")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="release_cargo",
            parameters=None
        )
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        cargo_q.put(event)

    def _calculate_bearing(self, start: GeoPoint, end: GeoPoint):
        delta_longitude = end.longitude - start.longitude
        x = math.sin(math.radians(delta_longitude)) * \
            math.cos(math.radians(end.latitude))
        y = math.cos(math.radians(start.latitude)) * math.sin(math.radians(end.latitude)) - \
            math.sin(math.radians(start.latitude)) * math.cos(math.radians(end.latitude)) * \
            math.cos(math.radians(delta_longitude))
        initial_bearing_rad = math.atan2(x, y)

        # Преобразуем радианы в градусы
        initial_bearing_deg = math.degrees(initial_bearing_rad)

        # Нормализуем значение в диапазоне [0, 360]
        compass_bearing = (initial_bearing_deg + 360) % 360

        return compass_bearing
        
# 2. напишите в этом блоке реализацию изменённых блоков связи, управления и навигации, 
# чтобы передавать данные согласно изменённой архитектуре на рис. 5 для обеспечения работы по сценарию на рис.6

# вставьте сюда ваш код
from src.control_system import BaseControlSystem
from src.navigation_system import BaseNavigationSystem
from src.communication_gateway import BaseCommunicationGateway
from multiprocessing import Queue
from src.config import SAFETY_BLOCK_QUEUE_NAME
from src.config import SERVOS_QUEUE_NAME
from src.config import CONTROL_SYSTEM_QUEUE_NAME
from src.event_types import Event


class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_speed", parameters=speed
                    ) # замените на код создания сообщения со скоростью для приводов
                           # подсказка, требуемая операция - set_speed

        # отправка сообщения с желаемым направлением
        event_direction = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_direction", parameters=direction
                    ) # замените на код создания сообщения с направлением для приводов
                               # подсказка, требуемая операция - set_direction

        safety_q.put(event_speed)
        safety_q.put(event_direction)  
        
    def _lock_cargo(self):
        """ заблокировать грузовой отсек """
        safety_q = self._queues_dir.get_queue(SAFETY_BLOCK_QUEUE_NAME)
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                    destination=SAFETY_BLOCK_QUEUE_NAME,
                    operation="lock_cargo", parameters= None
                    )
        safety_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """
        safety_q = self._queues_dir.get_queue(SAFETY_BLOCK_QUEUE_NAME)
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME, 
                    destination=SAFETY_BLOCK_QUEUE_NAME,
                    operation="release_cargo", parameters= None
                    )  
        safety_q.put(event)      


class CommunicationGateway(BaseCommunicationGateway):
    """CommunicationGateway класс для реализации логики взаимодействия
    с системой планирования заданий

    Работает в отдельном процессе, поэтому создаётся как наследник класса Process
    """
    def _send_mission_to_consumers(self):
        """ метод для отправки сообщения с маршрутным заданием в систему управления """
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)
                
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)


class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):        
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="position_update", parameters=self._position
                      )
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)
      
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        event =  Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="position_update", parameters=self._position
                    ) # замените на код создания сообщения с координатами для системы управления 
                     # подсказка, требуемая операция - position_update
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)
        
# создадим все остальные компоненты

# используем то же маршрутное задание, которое было в модуле 2
from time import sleep
from geopy import Point as GeoPoint


from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser


# возьмём маршрут из модуля 2
wpl_file = "module_2.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()
print(points)

from src.mission_type import GeoSpecificSpeedLimit
speed_limits = [
    GeoSpecificSpeedLimit(0, 20),
    GeoSpecificSpeedLimit(3, 50),
    GeoSpecificSpeedLimit(6, 20),
    GeoSpecificSpeedLimit(8, 50),
    GeoSpecificSpeedLimit(9, 20),
]


home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
################################

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)


system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ])

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(210)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [Point(59.8815191, 29.8300481, 0.0), Point(59.8819121, 29.8282993, 0.0), Point(59.8818098, 29.8277092, 0.0), Point(59.8818583, 29.8274088, 0.0), Point(59.8810884, 29.8267436, 0.0), Point(59.8796617, 29.8254454, 0.0), Point(59.8785849, 29.8245013, 0.0), Point(59.8781972, 29.8241472, 0.0), Point(59.8781003, 29.8241258, 0.0), Point(59.8780249, 29.8242867, 0.0), Point(59.8774811, 29.8267651, 0.0), Point(59.8769158, 29.8291469, 0.0), Point(59.8768512, 29.8291361, 0.0), Point(59.8765389, 29.8288143, 0.0), Point(59.8761512, 29.8284817, 0.0), Point(59.8756531, 29.8274866, 0.0), Point(59.8752903, 29.8277186, 0.0), Point(59.8751927, 29.8276126, 0.0), Point(59.875042, 29.8278809, 0.0), Point(59.8751443, 29.8284495, 0.0), Point(59.8751335, 29.8289645, 0.0), Point(59.8749935, 29.8295438, 0.0), Point(59.8747674, 29.829855, 0.0), Point(59.874455, 29.8299837, 0.0), Point(59.8742666, 29.8298872, 0.0)]
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][SAFETY] старт ограничителя
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 16:20:31.092019
# [ИНФО][SAFETY] Блокировка грузового отсека[ИНФО][CONTROL] новая скорость 20 (была 0)
#
# [ИНФО][CONTROL] новое направление 294 (было 0)
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4688s N, 29 49m 48.1732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4688s N, 29 49m 48.1732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4688s N, 29 49m 48.1732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4688s N, 29 49m 48.1732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.5054s N, 29 49m 48.0102s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.5348s N, 29 49m 47.8798s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.5715s N, 29 49m 47.7168s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.6082s N, 29 49m 47.5539s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.6449s N, 29 49m 47.3909s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.6815s N, 29 49m 47.2279s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7182s N, 29 49m 47.0649s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7549s N, 29 49m 46.9019s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7916s N, 29 49m 46.739s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.8283s N, 29 49m 46.576s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.8649s N, 29 49m 46.413s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.9016s N, 29 49m 46.25s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.9383s N, 29 49m 46.087s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.975s N, 29 49m 45.924s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.0116s N, 29 49m 45.761s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.0483s N, 29 49m 45.598s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.0849s N, 29 49m 45.435s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1216s N, 29 49m 45.272s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1583s N, 29 49m 45.109s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1949s N, 29 49m 44.946s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.2316s N, 29 49m 44.783s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.2682s N, 29 49m 44.62s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3049s N, 29 49m 44.457s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3415s N, 29 49m 44.294s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3782s N, 29 49m 44.1309s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4148s N, 29 49m 43.9679s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4514s N, 29 49m 43.8049s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.488s N, 29 49m 43.6419s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5247s N, 29 49m 43.4788s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5613s N, 29 49m 43.3158s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5979s N, 29 49m 43.1527s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6345s N, 29 49m 42.9897s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6711s N, 29 49m 42.8266s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7077s N, 29 49m 42.6636s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7443s N, 29 49m 42.5005s E
# [ИНФО][CONTROL] новое направление 293 (было 294)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7808s N, 29 49m 42.3374s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8174s N, 29 49m 42.1743s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 73 (было 293)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8539s N, 29 49m 42.0112s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 73.36063766292466. Скорректировано на 248.36063766292466
# [ИНФО][CONTROL] новое направление 70 (было 73)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8904s N, 29 49m 41.8481s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 70.36068445298747. Скорректировано на 245.36068445298747
# [ИНФО][CONTROL] новое направление 66 (было 70)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.9269s N, 29 49m 41.6849s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 66.99385244729308. Скорректировано на 241.9938524472931
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8938s N, 29 49m 41.5189s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 66.86977749814395. Скорректировано на 241.86977749814395
# [ИНФО][CONTROL] новое направление 67 (было 66)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8563s N, 29 49m 41.3566s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 67.0282808774507. Скорректировано на 242.0282808774507
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8142s N, 29 49m 41.1989s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 67.60725008184335. Скорректировано на 242.60725008184335
# [ИНФО][CONTROL] новое направление 68 (было 67)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7719s N, 29 49m 41.0414s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 68.35064785249159. Скорректировано на 243.3506478524916
# [ИНФО][CONTROL] новое направление 69 (было 68)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7298s N, 29 49m 40.8837s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 69.28910104684684. Скорректировано на 244.28910104684684
# [ИНФО][CONTROL] новое направление 70 (было 69)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6885s N, 29 49m 40.7251s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 70.45054811681916. Скорректировано на 245.45054811681916
# [ИНФО][CONTROL] новое направление 71 (было 70)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6482s N, 29 49m 40.5655s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 71.93917134957655. Скорректировано на 246.93917134957655
# [ИНФО][CONTROL] новое направление 73 (было 71)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6093s N, 29 49m 40.4046s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 73.95927412414335. Скорректировано на 248.95927412414338
# [ИНФО][CONTROL] новое направление 76 (было 73)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.572s N, 29 49m 40.2422s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 76.99024653142254. Скорректировано на 251.99024653142254
# [ИНФО][CONTROL] новое направление 82 (было 76)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5368s N, 29 49m 40.0779s E
# [ОШИБКА][SAFETY] попытка изменить направление движения не в ту сторону: 82.469303079128. Скорректировано на 257.469303079128
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 120 (была 20)
# [ИНФО][CONTROL] новое направление 286 (было 82)
# [ИНФО][SAFETY] сегмент пройден
# [ОШИБКА][SAFETY] попытка изменить скорость движения на запрещенную: 120. Скорректировано на 20
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5046s N, 29 49m 39.9112s E
# [ИНФО][CONTROL] новое направление 291 (было 286)
# [ОШИБКА][SAFETY] попытка изменить скорость движения на запрещенную: 120. Скорректировано на 20
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4768s N, 29 49m 39.7414s E
# [ИНФО][CONTROL] новое направление 297 (было 291)
# [ОШИБКА][SAFETY] попытка изменить скорость движения на запрещенную: 120. Скорректировано на 20
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4574s N, 29 49m 39.5671s E
# [ИНФО][CONTROL] новое направление 299 (было 297)
# [ОШИБКА][SAFETY] попытка изменить скорость движения на запрещенную: 120. Скорректировано на 20
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.483s N, 29 49m 39.396s E
# [ИНФО][CONTROL] новое направление 301 (было 299)
# [ОШИБКА][SAFETY] попытка изменить скорость движения на запрещенную: 120. Скорректировано на 20
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5161s N, 29 49m 39.23s E
# [ИНФО][CONTROL] новое направление 303 (было 301)
# [ОШИБКА][SAFETY] попытка изменить скорость движения на запрещенную: 120. Скорректировано на 20
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5574s N, 29 49m 39.0714s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 50 (была 120)
# [ИНФО][CONTROL] новое направление 206 (было 303)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6018s N, 29 49m 38.9162s E
# [ИНФО][CONTROL] новое направление 204 (было 206)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6495s N, 29 49m 38.765s E
# [ИНФО][CONTROL] новое направление 203 (было 204)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6489s N, 29 49m 38.6063s E
# [ИНФО][CONTROL] новое направление 202 (было 203)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4879s N, 29 49m 38.4482s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.2838s N, 29 49m 38.2626s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.0775s N, 29 49m 38.0869s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.8709s N, 29 49m 37.9127s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.6641s N, 29 49m 37.7394s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4573s N, 29 49m 37.5663s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.2504s N, 29 49m 37.3933s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.0435s N, 29 49m 37.2203s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.8367s N, 29 49m 37.0473s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.6298s N, 29 49m 36.8742s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.423s N, 29 49m 36.7011s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.2162s N, 29 49m 36.528s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 204 (было 202)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.0094s N, 29 49m 36.3547s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.8026s N, 29 49m 36.1812s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.5959s N, 29 49m 36.0074s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.3917s N, 29 49m 35.8221s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.1877s N, 29 49m 35.6364s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.9838s N, 29 49m 35.4501s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.7798s N, 29 49m 35.2638s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.5759s N, 29 49m 35.0774s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.372s N, 29 49m 34.8911s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.1681s N, 29 49m 34.7047s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.9642s N, 29 49m 34.5183s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.7603s N, 29 49m 34.3319s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.5564s N, 29 49m 34.1454s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.3526s N, 29 49m 33.959s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.1487s N, 29 49m 33.7725s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.9448s N, 29 49m 33.586s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.7409s N, 29 49m 33.3995s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.5371s N, 29 49m 33.213s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.3332s N, 29 49m 33.0264s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.1293s N, 29 49m 32.8398s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.9255s N, 29 49m 32.6532s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.7217s N, 29 49m 32.4665s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.5179s N, 29 49m 32.2797s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.3141s N, 29 49m 32.0929s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.1103s N, 29 49m 31.906s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 203 (было 204)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.9065s N, 29 49m 31.719s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.7028s N, 29 49m 31.5318s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.4988s N, 29 49m 31.3458s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.3346s N, 29 49m 31.2018s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.1291s N, 29 49m 31.0221s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.9236s N, 29 49m 30.8427s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.7181s N, 29 49m 30.6634s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.5127s N, 29 49m 30.4841s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.3072s N, 29 49m 30.3048s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.1017s N, 29 49m 30.1254s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.8962s N, 29 49m 29.9461s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.6907s N, 29 49m 29.7667s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.4852s N, 29 49m 29.5873s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.2798s N, 29 49m 29.4078s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.0743s N, 29 49m 29.2283s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.8689s N, 29 49m 29.0488s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.6634s N, 29 49m 28.8692s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.458s N, 29 49m 28.6896s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.2526s N, 29 49m 28.5099s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 50)
# [ИНФО][CONTROL] новое направление 204 (было 203)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.0472s N, 29 49m 28.3301s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.8418s N, 29 49m 28.1501s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.6366s N, 29 49m 27.9698s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.5545s N, 29 49m 27.8977s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.4728s N, 29 49m 27.8235s E
# [ИНФО][CONTROL] новое направление 205 (было 204)
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.3913s N, 29 49m 27.7489s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.3098s N, 29 49m 27.6738s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.2284s N, 29 49m 27.5986s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.1471s N, 29 49m 27.5232s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.0657s N, 29 49m 27.4477s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.9844s N, 29 49m 27.3722s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.903s N, 29 49m 27.2966s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.8217s N, 29 49m 27.2211s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.7404s N, 29 49m 27.1454s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.6591s N, 29 49m 27.0698s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 189 (было 205)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.5778s N, 29 49m 26.9941s E
# [ИНФО][CONTROL] новое направление 185 (было 189)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.4965s N, 29 49m 26.9183s E
# [ИНФО][CONTROL] новое направление 178 (было 185)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.4153s N, 29 49m 26.8425s E
# [ИНФО][CONTROL] новое направление 165 (было 178)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.3341s N, 29 49m 26.7665s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 40 (была 20)
# [ИНФО][CONTROL] новое направление 135 (было 165)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.2456s N, 29 49m 26.7365s E
# [ИНФО][CONTROL] новое направление 126 (было 135)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.1562s N, 29 49m 26.7191s E
# [ИНФО][CONTROL] новое направление 116 (было 126)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.0665s N, 29 49m 26.7228s E
# [ИНФО][CONTROL] новое направление 105 (было 116)
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.9794s N, 29 49m 26.7662s E
# [ИНФО][CONTROL] новое направление 79 (было 105)
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.8513s N, 29 49m 27.0163s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 40)
# [ИНФО][CONTROL] новое направление 111 (было 79)
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.744s N, 29 49m 27.3026s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.6641s N, 29 49m 27.6224s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.6175s N, 29 49m 27.9673s E
# [ИНФО][CONTROL] новое направление 113 (было 111)
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.65s N, 29 49m 28.3185s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.617s N, 29 49m 28.4846s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.5836s N, 29 49m 28.6503s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.5485s N, 29 49m 28.8146s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.5132s N, 29 49m 28.9788s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.478s N, 29 49m 29.143s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.4427s N, 29 49m 29.3072s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.4075s N, 29 49m 29.4714s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.3722s N, 29 49m 29.6356s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.3369s N, 29 49m 29.7998s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.3017s N, 29 49m 29.964s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.2664s N, 29 49m 30.1282s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.2382s N, 29 49m 30.2596s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.203s N, 29 49m 30.4238s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.1677s N, 29 49m 30.588s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.1325s N, 29 49m 30.7522s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.0972s N, 29 49m 30.9164s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.062s N, 29 49m 31.0806s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.0267s N, 29 49m 31.2449s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.9915s N, 29 49m 31.4091s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.9562s N, 29 49m 31.5733s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.921s N, 29 49m 31.7375s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.8857s N, 29 49m 31.9017s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.8505s N, 29 49m 32.0659s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.8153s N, 29 49m 32.2301s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.78s N, 29 49m 32.3944s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.7448s N, 29 49m 32.5586s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.7096s N, 29 49m 32.7228s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.6743s N, 29 49m 32.887s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.6391s N, 29 49m 33.0513s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.6039s N, 29 49m 33.2155s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.5687s N, 29 49m 33.3797s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.5334s N, 29 49m 33.544s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.4982s N, 29 49m 33.7082s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.463s N, 29 49m 33.8724s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.4278s N, 29 49m 34.0367s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.3926s N, 29 49m 34.2009s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.3574s N, 29 49m 34.3652s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.3222s N, 29 49m 34.5294s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.287s N, 29 49m 34.6937s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2518s N, 29 49m 34.8579s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2166s N, 29 49m 35.0222s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.1814s N, 29 49m 35.1865s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.1463s N, 29 49m 35.3507s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.1111s N, 29 49m 35.515s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.076s N, 29 49m 35.6793s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.0408s N, 29 49m 35.8436s E
# [ИНФО][CONTROL] новое направление 112 (было 113)
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.0057s N, 29 49m 36.0079s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 115 (было 112)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.9706s N, 29 49m 36.1722s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.9355s N, 29 49m 36.3366s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.9004s N, 29 49m 36.501s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.8621s N, 29 49m 36.6624s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.8238s N, 29 49m 36.8239s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7854s N, 29 49m 36.9852s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7469s N, 29 49m 37.1466s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7085s N, 29 49m 37.3079s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.6701s N, 29 49m 37.4693s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.6393s N, 29 49m 37.5984s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.6009s N, 29 49m 37.7598s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.5625s N, 29 49m 37.9211s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.5241s N, 29 49m 38.0825s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4857s N, 29 49m 38.2439s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4472s N, 29 49m 38.4052s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4088s N, 29 49m 38.5666s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.3704s N, 29 49m 38.728s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.332s N, 29 49m 38.8893s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.2936s N, 29 49m 39.0507s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.2552s N, 29 49m 39.2121s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.2168s N, 29 49m 39.3735s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.1784s N, 29 49m 39.5349s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.1399s N, 29 49m 39.6962s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.1015s N, 29 49m 39.8576s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.0631s N, 29 49m 40.019s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.0247s N, 29 49m 40.1804s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9863s N, 29 49m 40.3418s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9479s N, 29 49m 40.5031s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9095s N, 29 49m 40.6645s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.8711s N, 29 49m 40.8259s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.8327s N, 29 49m 40.9873s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.7944s N, 29 49m 41.1487s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.756s N, 29 49m 41.3101s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.7176s N, 29 49m 41.4715s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.6792s N, 29 49m 41.6329s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.6408s N, 29 49m 41.7943s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.6024s N, 29 49m 41.9557s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.5641s N, 29 49m 42.1171s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.5257s N, 29 49m 42.2785s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.4873s N, 29 49m 42.4399s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.449s N, 29 49m 42.6014s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.4106s N, 29 49m 42.7628s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.3722s N, 29 49m 42.9242s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.3339s N, 29 49m 43.0856s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.2955s N, 29 49m 43.2471s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.2572s N, 29 49m 43.4085s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.2188s N, 29 49m 43.5699s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.1805s N, 29 49m 43.7314s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.1422s N, 29 49m 43.8928s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.1039s N, 29 49m 44.0543s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.0656s N, 29 49m 44.2158s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.0273s N, 29 49m 44.3772s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.989s N, 29 49m 44.5387s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 161 (было 115)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.9507s N, 29 49m 44.7002s E
# [ИНФО][CONTROL] новое направление 176 (было 161)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.9125s N, 29 49m 44.8618s E
# [ИНФО][CONTROL] новое направление 197 (было 176)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.8743s N, 29 49m 45.0233s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 208 (было 197)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.7891s N, 29 49m 45.0797s E
# [ИНФО][CONTROL] новое направление 210 (было 208)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.6995s N, 29 49m 45.0898s E
# [ИНФО][CONTROL] новое направление 211 (было 210)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.6139s N, 29 49m 45.0356s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.535s N, 29 49m 44.9505s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.4576s N, 29 49m 44.86s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.381s N, 29 49m 44.767s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.3046s N, 29 49m 44.6734s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.2435s N, 29 49m 44.5984s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.1671s N, 29 49m 44.5046s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.0908s N, 29 49m 44.4107s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.0145s N, 29 49m 44.3167s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.9381s N, 29 49m 44.2228s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.8618s N, 29 49m 44.1288s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.7855s N, 29 49m 44.0348s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.7092s N, 29 49m 43.9408s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 203 (было 211)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.6329s N, 29 49m 43.8468s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.5566s N, 29 49m 43.7527s E
# [ИНФО][CONTROL] новое направление 202 (было 203)
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.4804s N, 29 49m 43.6584s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.3983s N, 29 49m 43.5862s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.3159s N, 29 49m 43.5152s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.2332s N, 29 49m 43.4458s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.1505s N, 29 49m 43.3763s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.0678s N, 29 49m 43.307s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.9851s N, 29 49m 43.2378s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.9023s N, 29 49m 43.1687s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.8196s N, 29 49m 43.0995s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.7368s N, 29 49m 43.0304s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.6541s N, 29 49m 42.9612s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.5713s N, 29 49m 42.8921s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.4886s N, 29 49m 42.8229s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.4058s N, 29 49m 42.7537s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.3231s N, 29 49m 42.6845s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 224 (было 202)
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.2403s N, 29 49m 42.6153s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.1576s N, 29 49m 42.546s E
# [ИНФО][CONTROL] новое направление 225 (было 224)
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.0749s N, 29 49m 42.4766s E
# [ИНФО][CONTROL] новое направление 226 (было 225)
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.9922s N, 29 49m 42.4072s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.9287s N, 29 49m 42.281s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.8661s N, 29 49m 42.1532s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.8044s N, 29 49m 42.0235s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.7427s N, 29 49m 41.8936s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.6812s N, 29 49m 41.7637s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.6196s N, 29 49m 41.6338s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.558s N, 29 49m 41.5039s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.4965s N, 29 49m 41.374s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.4349s N, 29 49m 41.244s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.3734s N, 29 49m 41.1141s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.3118s N, 29 49m 40.9841s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.2503s N, 29 49m 40.8542s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.1887s N, 29 49m 40.7242s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.1272s N, 29 49m 40.5942s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.0657s N, 29 49m 40.4642s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.0041s N, 29 49m 40.3342s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.9549s N, 29 49m 40.2302s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.8934s N, 29 49m 40.1002s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.8319s N, 29 49m 39.9702s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.7704s N, 29 49m 39.8402s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.7089s N, 29 49m 39.7101s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.6474s N, 29 49m 39.5801s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.5859s N, 29 49m 39.45s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.5244s N, 29 49m 39.3199s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.463s N, 29 49m 39.1898s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 164 (было 226)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.4015s N, 29 49m 39.0596s E
# [ИНФО][CONTROL] новое направление 161 (было 164)
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.3401s N, 29 49m 38.9293s E
# [ИНФО][CONTROL] новое направление 158 (было 161)
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.2788s N, 29 49m 38.799s E
# [ИНФО][CONTROL] новое направление 157 (было 158)
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.1921s N, 29 49m 38.8454s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.1069s N, 29 49m 38.9017s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.0237s N, 29 49m 38.9683s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.9407s N, 29 49m 39.0363s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.8579s N, 29 49m 39.1052s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.7751s N, 29 49m 39.1743s E
# Process ControlSystem-35:
# Process MissionSender-39:
# Process CargoBay-44:
# Process TelemetrySender-40:
# Process SafetyBlock-45:
# Process SITL-42:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 355
#     352 system_components.start()
#     354 # настройте этот параметр так, чтобы проверить работу ограничителя
# --> 355 sleep(210)
#     357 # останавливаем все компоненты
#     358 system_components.stop()
#
# KeyboardInterrupt:
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/root/cyberimmune-autonomy--chvt-preview/src/safety_block.py", line 178, in run
#     sleep(self._recalc_interval_sec)
# KeyboardInterrupt
# Process NavigationSystem-36:
# Process CommunicationGateway-34:
#   File "/root/cyberimmune-autonomy--chvt-preview/src/mission_planner_mqtt.py", line 160, in run
#     sleep(self._recalc_interval_sec)
# Traceback (most recent call last):
#   File "/root/cyberimmune-autonomy--chvt-preview/src/cargo_bay.py", line 110, in run
#     sleep(self._recalc_interval_sec)
# Process Servos-43:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/root/cyberimmune-autonomy--chvt-preview/src/sitl.py", line 186, in run
#     sleep(self._recalc_interval_sec)
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/root/cyberimmune-autonomy--chvt-preview/src/control_system.py", line 268, in run
#     sleep(self._recalc_interval_sec)
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process MissionPlanner-41:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/root/cyberimmune-autonomy--chvt-preview/src/navigation_system.py", line 107, in run
#     sleep(self._recalc_interval_sec)
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/root/cyberimmune-autonomy--chvt-preview/src/communication_gateway.py", line 108, in run
#     sleep(self._recalc_interval_sec)
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/root/cyberimmune-autonomy--chvt-preview/src/sitl_mqtt.py", line 162, in run
#     sleep(self._recalc_interval_sec)
#   File "/root/cyberimmune-autonomy--chvt-preview/src/servos.py", line 141, in run
#     sleep(self._recalc_interval_sec)
# KeyboardInterrupt
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/root/cyberimmune-autonomy--chvt-preview/src/mission_planner.py", line 180, in run
#     sleep(self._recalc_interval_sec)
# KeyboardInterrupt
# KeyboardInterrupt

# %% [markdown]
# #### *Опциональное задание повышенной сложности* Обеспечение ЦБ2
#
# **Перед началом работы над этой задачей рекомендуем сохранить все текущие изменения в git репозитории (git commit, git push).**
#
# Напомним цель безопасности №2 (ЦБ2): "При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут"
#
# Обеспечение ЦБ2 потребует
# - внедрения механизма **контроля аутентичности маршрутного задания** (mission), а значит
# - помимо изменения **блока безопасности** (SafetyBlock), модификации
#   - системы **планирования задания** (MissionPlanner)
#   - **коммуникационного шлюза** (CommunicationGateway)
#   - и, возможно, **системы управления** (ControlSystem).
#
# Для решения этой задачи допустимо менять код соответствующих модулей в папке src.
#
# Возможным решением является внедрение механизма цифровой подписи, верификацией которой будет заниматься блок безопасности. В этой ситуации если коммуникационный шлюз (блок "1. Связь" на рис. 5 в модуле 1) оказался скомпрометированным и изменил маршрутное задание, оно не должно пройти проверку подлинности в блоке безопасности.
#
# **Рекомендуем эту задачу делать в последнюю очередь**, *после успешного выполнения модуля 4*, поскольку успешное выполнение модуля 4 принесёт больше баллов, чем внедрение цифровой подписи и обеспечение ЦБ2.
# К сведению, реализованные в этой версии киберпрепятствия не предполагают компрометацию маршрутного задания.
#
# Конечно, если будут решены все основные задачи и к тому же обеспечен контроль аутентичности маршрутного задания, такая работа с высокой вероятностью окажется лучшей.

# %%
# если вы собираетесь выполнить это задание, напишите в этой ячейке код выполнения изменённых блоков. 
# cам код допускается редактировать в папке src
# в случае успешной реализации машинка должна успешно пройти по маршруту, а в случае искажения маршрутного задания в блоке коммуникационного шлюза должна остаться на месте, 
# при этом именно блок безопасности должен заблокировать движение

# %% [markdown]
# ### Задание 3.2. Монитор безопасности

# %% [markdown]
# В текущей реализации каждый блок сам решает куда и какие данные ему отправлять. Это приемлемо, когда каждый блок рассматривается как благонадёжный. Однако нельзя исключать ситуацию успешной компрометации какого-либо из блоков (одного или нескольких), в результате которой злоумышленник может получить полный контроль над частью системы.
#
# В такой ситуации необходимо выстроить внутреннюю "поверхность защиты", частью этой системы уже является блок "Ограничитель", однако необходимо сделать так, чтобы соответствующие запросы проходили только через него, а не в обход.
#
# Для решения этой задачи необходимо добавить новый блок "Монитор безопасности". Его задача - обеспечить контроль направления информационных потоков, допустить передачу данных только между теми блоками и в тех направлениях, которые задуманы архитектором системы. Тогда, например, попытка передать команду из системы управления напрямую в сервоприводы в обход ограничителя будет заблокирована.
#
# Возможно, возникнет вопрос, а что помешает злоумышленнику отправить команду в обход этого монитора безопасности. В рамках этой учебной инфраструктуры особо ничего, однако при разработке реальной системы можно использовать специализированные микроядерные операционные системы, такие как, например, KasperskyOS, которые обеспечат обязательное вовлечение монитора безопасности в контроль взаимодействия между блоками.
#
# Архитектура системы для решения задачи 3.2 должна выглядеть как на рис.8:
#
# ![Архитектура системы с монитором безопасности](images/ciac-arch-m32.png)
#
# Рис. 8. Архитектура бортовых систем с монитором безопасности

# %% [markdown]
# Базовый класс модуля безопасности находится в файле src/security_monitor.py, его менять не нужно.
#
# В следующей ячейке находится реализация класса SecurityMonitor

# %%
from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import COMMUNICATION_GATEWAY_QUEUE_NAME, LOG_DEBUG, LOG_ERROR, LOG_INFO
    
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission')
        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized

# %% [markdown]
# Обратите внимание на этот код:
# ```python
#     def _init_set_security_policies(self):
#         """ инициализация политик безопасности """
#         default_policies = [
#             SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
#         ]
#         self.set_security_policies(policies=default_policies)
# ```
#
# В нём инициализируется политика безопасности, разрешающая запрос set_mission от коммуникационного шлюза в систему управления.
#
# Код политики безопасности в строка 6-9:
# ```python
# SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
# ```
#
# Шаблон политики безопасности описан в файле src/security_policy_type.py:
# ```python
# @dataclass
# class SecurityPolicy:
#     """ политика безопасности """
#     source: str         # отправитель запроса
#     destination: str    # получатель
#     operation: str      # запрашиваемая операция
#
# ```
#
# По аналогии в методе _init_set_security_policies допишите другие политики безопасности, чтобы разрешить взаимодействия согласно диаграмме на рис.7. выше.

# %% [markdown]
# Теперь необходимо изменить взаимодействие между блоками так, чтобы оно всегда проходило через монитор безопасности. Для этого потребуется изменить соответствующие реализации внутренних блоков.

# %% [markdown]
# Ниже пример для блока навигации. Обратите внимание на выделенные строки и комментарии.
#
# ```python
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         # событие для системы управления,
#         # поэтому в destination указываем CONTROL_SYSTEM_QUEUE_NAME
#         event = Event(source=self.event_source_name,
# >>>                      destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         # но событие отправляем сначала на проверку в монитор безопасности,
#         # поэтому используем очередь с именем SECURITY_MONITOR_QUEUE_NAME
# >>>        security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#         # а в систему управления наше событие монитор безопасности отправит сам, если найдёт разрешающую эту операцию политику безопасности
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)
# ```

# %% [markdown]
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         event = Event(source=self.event_source_name,
#                       destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)

# %% [markdown]
# В файле tests/module/test_security_monitor.py можно увидеть тест логики работы монитора безопасности. Запустить его можно следующей командой:

# %%
# !pytest -svk security_monitor
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.3, pytest-8.3.4, pluggy-1.5.0 -- /root/cyberimmune-autonomy--chvt-preview/env/bin/python3
# cachedir: .pytest_cache
# rootdir: /root/cyberimmune-autonomy--chvt-preview
# configfile: pytest.ini
# testpaths: tests
# collected 1 item
#
# tests/module/test_security_monitor.py::test_security_policies [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь security
# [ИНФО][SECURITY] создан монитор безопасности
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission')]
# [ОТЛАДКА][SECURITY] проверка события Event(source='communication', destination='control', operation='set_mission', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ОТЛАДКА][SECURITY] событие разрешено политиками, выполняем
# [ОТЛАДКА][SECURITY] проверка события Event(source='control', destination='safety', operation='set_speed', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission'), SecurityPolicy(source='control', destination='safety', operation='set_speed')]
# [ОТЛАДКА][SECURITY] проверка события Event(source='control', destination='safety', operation='set_speed', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ОТЛАДКА][SECURITY] событие разрешено политиками, выполняем
# [ОТЛАДКА][SECURITY] проверка события Event(source='communication', destination='cargo', operation='release_cargo', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# PASSED
#
# ============================== 1 passed in 0.01s ===============================

# %% [markdown]
# В одном кодовом блоке ниже (или нескольких - как будет удобнее)  сделайте следующее
#
# 1. Измените реализацию монитора безопасности в части правил проверки передаваемых сообщений в мониторе безопасности
# 2. Измените параметры отправки сообщений между элементами бортовых систем (блоками 1-7), чтобы они всегда отправлялись в очередь монитора безопасности (отправитель и получатель при этом не меняются)
# 3. После всех изменений убедитесь в том, что машинка по-прежнему успешно выполняет маршрутное задание и доставляет груз
# 4. Дополнительные баллы принесут автоматические тесты правил безопасности в файле tests/module/test_security_monitor.py - можно проверить, что все новые политики работают как ожидаются, а недопустимые взаимодействия (т.е. таких стрелок нет на рис. 8) блокируются

# %%
# добавьте изменения сюда

from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import *
    
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission'),
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="set_mission"),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=NAVIGATION_QUEUE_NAME,
                operation="request_position"),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="position_update"),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation="position_update"),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="set_speed"),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="set_direction"),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="lock_cargo"),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="release_cargo"),            
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation="set_speed"),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation="set_direction"),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation="release_cargo"),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation="lock_cargo"),
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='position_update'),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="position_update"),
        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized

# %%
from src.safety_block import BaseSafetyBlock
from src.config import *
import math
from time import sleep
from geopy import Point as GeoPoint
from src.config import LOG_ERROR, LOG_INFO, LOG_DEBUG
from multiprocessing import Queue
from src.config import SERVOS_QUEUE_NAME
from src.event_types import Event


# 2. напишите в этом блоке реализацию изменённых блоков связи, управления и навигации, 
# чтобы передавать данные согласно изменённой архитектуре на рис. 5 для обеспечения работы по сценарию на рис.6

# вставьте сюда ваш код
from src.control_system import BaseControlSystem
from src.navigation_system import BaseNavigationSystem
from src.communication_gateway import BaseCommunicationGateway
from multiprocessing import Queue
from src.config import SAFETY_BLOCK_QUEUE_NAME
from src.config import SERVOS_QUEUE_NAME
from src.config import CONTROL_SYSTEM_QUEUE_NAME
from src.event_types import Event


class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_speed", parameters=speed
                    ) # замените на код создания сообщения со скоростью для приводов
                           # подсказка, требуемая операция - set_speed

        # отправка сообщения с желаемым направлением
        event_direction = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_direction", parameters=direction
                    ) # замените на код создания сообщения с направлением для приводов
                               # подсказка, требуемая операция - set_direction

        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event_direction)
        security_monitor_q.put(event_speed)
        
    def _lock_cargo(self):
        """ заблокировать грузовой отсек """
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                    destination=SAFETY_BLOCK_QUEUE_NAME,
                    operation="lock_cargo", parameters= None
                    )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME, 
                    destination=SAFETY_BLOCK_QUEUE_NAME,
                    operation="release_cargo", parameters= None
                    )  
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)


class CommunicationGateway(BaseCommunicationGateway):
    """CommunicationGateway класс для реализации логики взаимодействия
    с системой планирования заданий

    Работает в отдельном процессе, поэтому создаётся как наследник класса Process
    """
    def _send_mission_to_consumers(self):
        """ метод для отправки сообщения с маршрутным заданием в систему управления """
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)
                
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)


class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):        
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="position_update", parameters=self._position
                      )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)
      
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        event =  Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="position_update", parameters=self._position
                    ) # замените на код создания сообщения с координатами для системы управления 
                     # подсказка, требуемая операция - position_update
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)

class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        # TODO реализовать контроль безопасности изменения направления

        if not self._position or not self._route:
            return
        
        current = self._position
        next = self._route.next_point()
        bearing = self._calculate_bearing(current, next)
        
        direction = max(bearing - 5, min(bearing + 5, direction))
                
        self._direction = direction
        # отправка сообщения с желаемым направлением
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        if not self._route:
            return

        speed = max(0, min(speed, self._route.calculate_speed()))

        self._speed = speed
        self._send_speed_to_consumers()

    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event_speed)

    def _lock_cargo(self, _):
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._send_lock_cargo_to_consumers()

    def _send_lock_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду блокировки в CargoBay")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="lock_cargo",
            parameters=None
        )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)
        
    def _release_cargo(self, _):
        if not self._route or not self._route.route_finished:
            self._log_message(LOG_DEBUG, "Не разрешили открыть груз тк не на маршруте или не закончили его")
            return
        self._send_release_cargo_to_consumers()

    def _send_release_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду выгрузки в CargoBay")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="release_cargo",
            parameters=None
        )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)

    def _calculate_bearing(self, start: GeoPoint, end: GeoPoint):
        delta_longitude = end.longitude - start.longitude
        x = math.sin(math.radians(delta_longitude)) * \
            math.cos(math.radians(end.latitude))
        y = math.cos(math.radians(start.latitude)) * math.sin(math.radians(end.latitude)) - \
            math.sin(math.radians(start.latitude)) * math.cos(math.radians(end.latitude)) * \
            math.cos(math.radians(delta_longitude))
        initial_bearing_rad = math.atan2(x, y)

        # Преобразуем радианы в градусы
        initial_bearing_deg = math.degrees(initial_bearing_rad)

        # Нормализуем значение в диапазоне [0, 360]
        compass_bearing = (initial_bearing_deg + 360) % 360

        return compass_bearing
        
# используем то же маршрутное задание, которое было в модуле 2
from time import sleep
from geopy import Point as GeoPoint


from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser


# возьмём маршрут из модуля 2
wpl_file = "module_2.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()
print(points)

from src.mission_type import GeoSpecificSpeedLimit
speed_limits = [
    GeoSpecificSpeedLimit(0, 20),
    GeoSpecificSpeedLimit(3, 50),
    GeoSpecificSpeedLimit(6, 20),
    GeoSpecificSpeedLimit(8, 50),
    GeoSpecificSpeedLimit(9, 20),
]


home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
################################

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)

security_monitor = SecurityMonitor(queues_dir=queues_dir)

system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        security_monitor,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        security_monitor,
        communication_gateway,
        control_system,
        safety_block
    ])

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(210)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [Point(59.8815191, 29.8300481, 0.0), Point(59.8819121, 29.8282993, 0.0), Point(59.8818098, 29.8277092, 0.0), Point(59.8818583, 29.8274088, 0.0), Point(59.8810884, 29.8267436, 0.0), Point(59.8796617, 29.8254454, 0.0), Point(59.8785849, 29.8245013, 0.0), Point(59.8781972, 29.8241472, 0.0), Point(59.8781003, 29.8241258, 0.0), Point(59.8780249, 29.8242867, 0.0), Point(59.8774811, 29.8267651, 0.0), Point(59.8769158, 29.8291469, 0.0), Point(59.8768512, 29.8291361, 0.0), Point(59.8765389, 29.8288143, 0.0), Point(59.8761512, 29.8284817, 0.0), Point(59.8756531, 29.8274866, 0.0), Point(59.8752903, 29.8277186, 0.0), Point(59.8751927, 29.8276126, 0.0), Point(59.875042, 29.8278809, 0.0), Point(59.8751443, 29.8284495, 0.0), Point(59.8751335, 29.8289645, 0.0), Point(59.8749935, 29.8295438, 0.0), Point(59.8747674, 29.829855, 0.0), Point(59.874455, 29.8299837, 0.0), Point(59.8742666, 29.8298872, 0.0)]
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель
# [ИНФО][QUEUES] регистрируем очередь security
# [ИНФО][SECURITY] создан монитор безопасности
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission'), SecurityPolicy(source='communication', destination='safety', operation='set_mission'), SecurityPolicy(source='control', destination='navigation', operation='request_position'), SecurityPolicy(source='navigation', destination='safety', operation='position_update'), SecurityPolicy(source='navigation', destination='control', operation='position_update'), SecurityPolicy(source='control', destination='safety', operation='set_speed'), SecurityPolicy(source='control', destination='safety', operation='set_direction'), SecurityPolicy(source='control', destination='safety', operation='lock_cargo'), SecurityPolicy(source='control', destination='safety', operation='release_cargo'), SecurityPolicy(source='safety', destination='servos', operation='set_speed'), SecurityPolicy(source='safety', destination='servos', operation='set_direction'), SecurityPolicy(source='safety', destination='cargo', operation='release_cargo'), SecurityPolicy(source='safety', destination='cargo', operation='lock_cargo'), SecurityPolicy(source='communication', destination='control', operation='position_update'), SecurityPolicy(source='control', destination='safety', operation='position_update')]
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][SECURITY] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][SAFETY] старт ограничителя
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 16:37:49.201956
# [ИНФО][SAFETY] Блокировка грузового отсека
# [ИНФО][CONTROL] новая скорость 20 (была 0)
# [ИНФО][CONTROL] новое направление 294 (было 0)
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4688s N, 29 49m 48.1732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4688s N, 29 49m 48.1732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4688s N, 29 49m 48.1732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4688s N, 29 49m 48.1732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.5054s N, 29 49m 48.0102s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.5421s N, 29 49m 47.8472s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.5715s N, 29 49m 47.7168s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.6082s N, 29 49m 47.5539s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.6449s N, 29 49m 47.3909s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.6815s N, 29 49m 47.2279s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7182s N, 29 49m 47.0649s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7549s N, 29 49m 46.9019s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7916s N, 29 49m 46.739s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.8283s N, 29 49m 46.576s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.865s N, 29 49m 46.413s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.9016s N, 29 49m 46.25s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.9383s N, 29 49m 46.087s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.975s N, 29 49m 45.924s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.0116s N, 29 49m 45.761s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.0483s N, 29 49m 45.598s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.085s N, 29 49m 45.435s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1216s N, 29 49m 45.272s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1583s N, 29 49m 45.109s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1949s N, 29 49m 44.946s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.2316s N, 29 49m 44.783s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.2682s N, 29 49m 44.62s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3049s N, 29 49m 44.457s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3415s N, 29 49m 44.294s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3782s N, 29 49m 44.131s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4075s N, 29 49m 44.0005s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4441s N, 29 49m 43.8375s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4807s N, 29 49m 43.6745s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5174s N, 29 49m 43.5114s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.554s N, 29 49m 43.3484s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5906s N, 29 49m 43.1854s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6272s N, 29 49m 43.0223s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6638s N, 29 49m 42.8593s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7004s N, 29 49m 42.6962s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.737s N, 29 49m 42.5331s E
# [ИНФО][CONTROL] новое направление 293 (было 294)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7735s N, 29 49m 42.37s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8101s N, 29 49m 42.2069s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 73 (было 293)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8466s N, 29 49m 42.0438s E
# [ИНФО][CONTROL] новое направление 70 (было 73)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8831s N, 29 49m 41.8807s E
# [ИНФО][CONTROL] новое направление 67 (было 70)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.9196s N, 29 49m 41.7175s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8873s N, 29 49m 41.5509s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8508s N, 29 49m 41.3878s E
# [ИНФО][CONTROL] новое направление 68 (было 67)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8096s N, 29 49m 41.2291s E
# [ИНФО][CONTROL] новое направление 69 (было 68)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7683s N, 29 49m 41.0706s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7272s N, 29 49m 40.9118s E
# [ИНФО][CONTROL] новое направление 71 (было 69)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6869s N, 29 49m 40.7522s E
# [ИНФО][CONTROL] новое направление 72 (было 71)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6476s N, 29 49m 40.5916s E
# [ИНФО][CONTROL] новое направление 74 (было 72)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6097s N, 29 49m 40.4298s E
# [ИНФО][CONTROL] новое направление 77 (было 74)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5733s N, 29 49m 40.2666s E
# [ИНФО][CONTROL] новое направление 82 (было 77)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.539s N, 29 49m 40.1015s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 120 (была 20)
# [ИНФО][CONTROL] новое направление 286 (было 82)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5075s N, 29 49m 39.9343s E
# [ИНФО][CONTROL] новое направление 291 (было 286)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.476s N, 29 49m 39.7671s E
# [ИНФО][CONTROL] новое направление 297 (было 291)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4488s N, 29 49m 39.5969s E
# [ИНФО][CONTROL] новое направление 304 (было 297)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.429s N, 29 49m 39.4228s E
# [ИНФО][CONTROL] новое направление 309 (было 304)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4538s N, 29 49m 39.2511s E
# [ИНФО][CONTROL] новое направление 314 (было 309)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4864s N, 29 49m 39.0847s E
# [ИНФО][CONTROL] новое направление 321 (было 314)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5277s N, 29 49m 38.9262s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 50 (была 120)
# [ИНФО][CONTROL] новое направление 205 (было 321)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5788s N, 29 49m 38.7794s E
# [ИНФО][CONTROL] новое направление 203 (было 205)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6367s N, 29 49m 38.643s E
# [ИНФО][CONTROL] новое направление 202 (было 203)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.687s N, 29 49m 38.5411s E
# [ИНФО][CONTROL] новое направление 200 (было 202)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7575s N, 29 49m 38.4306s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5545s N, 29 49m 38.24s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3489s N, 29 49m 38.0614s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1413s N, 29 49m 37.8919s E
# [ИНФО][CONTROL] новое направление 199 (было 200)
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.9316s N, 29 49m 37.7331s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7214s N, 29 49m 37.5768s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.5108s N, 29 49m 37.4225s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.3s N, 29 49m 37.2696s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.0891s N, 29 49m 37.1173s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.8781s N, 29 49m 36.9654s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.667s N, 29 49m 36.8139s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.4559s N, 29 49m 36.6625s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.2448s N, 29 49m 36.5112s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 204 (было 199)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.0336s N, 29 49m 36.36s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.8225s N, 29 49m 36.2089s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.6113s N, 29 49m 36.0577s E
# [ИНФО][CONTROL] новое направление 205 (было 204)
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.4002s N, 29 49m 35.9065s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.1959s N, 29 49m 35.7218s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.9919s N, 29 49m 35.5357s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.7883s N, 29 49m 35.3482s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.585s N, 29 49m 35.1591s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.3818s N, 29 49m 34.9698s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.1786s N, 29 49m 34.7803s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.9755s N, 29 49m 34.5908s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.7723s N, 29 49m 34.4011s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.5692s N, 29 49m 34.2115s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.3661s N, 29 49m 34.0218s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.1629s N, 29 49m 33.8321s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.0004s N, 29 49m 33.6803s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.7973s N, 29 49m 33.4906s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.5942s N, 29 49m 33.3008s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.3911s N, 29 49m 33.111s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.188s N, 29 49m 32.9212s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.9849s N, 29 49m 32.7313s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.7818s N, 29 49m 32.5413s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.5788s N, 29 49m 32.3513s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.3758s N, 29 49m 32.1613s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.1727s N, 29 49m 31.9711s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.9697s N, 29 49m 31.7809s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 203 (было 205)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.7668s N, 29 49m 31.5905s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.5639s N, 29 49m 31.3998s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.3611s N, 29 49m 31.2084s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.1558s N, 29 49m 31.0286s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.9502s N, 29 49m 30.8494s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.7446s N, 29 49m 30.6709s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.5389s N, 29 49m 30.4925s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.3332s N, 29 49m 30.3141s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.1275s N, 29 49m 30.1357s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.9218s N, 29 49m 29.9573s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.7161s N, 29 49m 29.7789s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.5104s N, 29 49m 29.6004s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.3047s N, 29 49m 29.4219s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.0991s N, 29 49m 29.2434s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.8934s N, 29 49m 29.0648s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.6877s N, 29 49m 28.8862s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.4821s N, 29 49m 28.7075s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.2765s N, 29 49m 28.5288s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.0709s N, 29 49m 28.3499s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 50)
# [ИНФО][CONTROL] новое направление 204 (было 203)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.8653s N, 29 49m 28.1709s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.6598s N, 29 49m 27.9916s E
# [ИНФО][CONTROL] новое направление 205 (было 204)
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.4545s N, 29 49m 27.8115s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.3729s N, 29 49m 27.7369s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.2915s N, 29 49m 27.6619s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.2102s N, 29 49m 27.5861s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.129s N, 29 49m 27.5103s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.0477s N, 29 49m 27.4343s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.9665s N, 29 49m 27.3584s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.9015s N, 29 49m 27.2975s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.8203s N, 29 49m 27.2215s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.7391s N, 29 49m 27.1454s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.6579s N, 29 49m 27.0693s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 189 (было 205)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.5767s N, 29 49m 26.9932s E
# [ИНФО][CONTROL] новое направление 185 (было 189)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.4956s N, 29 49m 26.917s E
# [ИНФО][CONTROL] новое направление 178 (было 185)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.4144s N, 29 49m 26.8407s E
# [ИНФО][CONTROL] новое направление 172 (было 178)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.3259s N, 29 49m 26.8109s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 40 (была 20)
# [ИНФО][CONTROL] новое направление 137 (было 172)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.2366s N, 29 49m 26.7938s E
# [ИНФО][CONTROL] новое направление 128 (было 137)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.1468s N, 29 49m 26.7981s E
# [ИНФО][CONTROL] новое направление 118 (было 128)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.0578s N, 29 49m 26.8207s E
# [ИНФО][CONTROL] новое направление 101 (было 118)
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.9259s N, 29 49m 27.063s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 40)
# [ИНФО][CONTROL] новое направление 112 (было 101)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.8131s N, 29 49m 27.3407s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.7268s N, 29 49m 27.6539s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.6923s N, 29 49m 28.0043s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.6578s N, 29 49m 28.1692s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.6237s N, 29 49m 28.3344s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.5889s N, 29 49m 28.499s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.5542s N, 29 49m 28.6636s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.5194s N, 29 49m 28.8282s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.4846s N, 29 49m 28.9928s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.4498s N, 29 49m 29.1574s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.4151s N, 29 49m 29.322s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.3803s N, 29 49m 29.4866s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.3455s N, 29 49m 29.6512s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.3107s N, 29 49m 29.8158s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.276s N, 29 49m 29.9805s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.2412s N, 29 49m 30.1451s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.2064s N, 29 49m 30.3097s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.1716s N, 29 49m 30.4743s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.1369s N, 29 49m 30.6389s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.1021s N, 29 49m 30.8035s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.0673s N, 29 49m 30.9681s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.0326s N, 29 49m 31.1328s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.9978s N, 29 49m 31.2974s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.97s N, 29 49m 31.4291s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.9353s N, 29 49m 31.5937s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.9005s N, 29 49m 31.7583s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.8657s N, 29 49m 31.9229s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.831s N, 29 49m 32.0876s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.7962s N, 29 49m 32.2522s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.7615s N, 29 49m 32.4168s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.7267s N, 29 49m 32.5814s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.692s N, 29 49m 32.7461s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.6572s N, 29 49m 32.9107s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.6225s N, 29 49m 33.0754s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.5878s N, 29 49m 33.24s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.553s N, 29 49m 33.4046s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.5183s N, 29 49m 33.5693s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.4836s N, 29 49m 33.7339s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.4489s N, 29 49m 33.8986s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.4141s N, 29 49m 34.0632s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.3794s N, 29 49m 34.2279s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.3447s N, 29 49m 34.3925s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.31s N, 29 49m 34.5572s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2753s N, 29 49m 34.7219s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2406s N, 29 49m 34.8865s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2059s N, 29 49m 35.0512s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.1712s N, 29 49m 35.2159s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.1434s N, 29 49m 35.3476s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.1088s N, 29 49m 35.5123s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.0741s N, 29 49m 35.677s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.0394s N, 29 49m 35.8417s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.0048s N, 29 49m 36.0064s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 115 (было 112)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.9702s N, 29 49m 36.1712s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.9356s N, 29 49m 36.3359s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.901s N, 29 49m 36.5007s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.8634s N, 29 49m 36.6628s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.8251s N, 29 49m 36.8243s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7867s N, 29 49m 36.9856s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7482s N, 29 49m 37.147s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7098s N, 29 49m 37.3083s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.6713s N, 29 49m 37.4697s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.6329s N, 29 49m 37.631s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.5944s N, 29 49m 37.7924s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.556s N, 29 49m 37.9537s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.5176s N, 29 49m 38.115s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4791s N, 29 49m 38.2764s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4407s N, 29 49m 38.4377s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4022s N, 29 49m 38.5991s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.3638s N, 29 49m 38.7604s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.3254s N, 29 49m 38.9218s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.2869s N, 29 49m 39.0831s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.2485s N, 29 49m 39.2445s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.2101s N, 29 49m 39.4058s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.1716s N, 29 49m 39.5672s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.1332s N, 29 49m 39.7286s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.0948s N, 29 49m 39.8899s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.0563s N, 29 49m 40.0513s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.0256s N, 29 49m 40.1804s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9872s N, 29 49m 40.3417s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9487s N, 29 49m 40.5031s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9103s N, 29 49m 40.6645s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.8719s N, 29 49m 40.8258s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.8335s N, 29 49m 40.9872s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.7951s N, 29 49m 41.1486s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.7567s N, 29 49m 41.3099s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.7182s N, 29 49m 41.4713s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.6798s N, 29 49m 41.6327s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.6414s N, 29 49m 41.7941s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.603s N, 29 49m 41.9554s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.5646s N, 29 49m 42.1168s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.5262s N, 29 49m 42.2782s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.4878s N, 29 49m 42.4396s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.4494s N, 29 49m 42.601s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.411s N, 29 49m 42.7624s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.3727s N, 29 49m 42.9238s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.3343s N, 29 49m 43.0852s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.2959s N, 29 49m 43.2466s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.2575s N, 29 49m 43.408s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.2192s N, 29 49m 43.5694s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.1808s N, 29 49m 43.7308s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.1424s N, 29 49m 43.8923s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.1041s N, 29 49m 44.0537s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.0658s N, 29 49m 44.2151s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.0274s N, 29 49m 44.3766s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.9968s N, 29 49m 44.5058s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 159 (было 115)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.9585s N, 29 49m 44.6672s E
# [ИНФО][CONTROL] новое направление 173 (было 159)
# [ИНФО][CONTROL] новое направление 193 (было 173)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.9202s N, 29 49m 44.8287s E
# [ИНФО][CONTROL] новое направление 216 (было 193)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.8819s N, 29 49m 44.9903s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.8437s N, 29 49m 45.1518s E
# [ИНФО][CONTROL] новое направление 239 (было 216)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.7598s N, 29 49m 45.2152s E
# [ИНФО][CONTROL] новое направление 267 (было 239)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.6707s N, 29 49m 45.2365s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 213 (было 267)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.5983s N, 29 49m 45.131s E
# [ИНФО][CONTROL] новое направление 211 (было 213)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.553s N, 29 49m 44.9769s E
# [ИНФО][CONTROL] новое направление 207 (было 211)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.5497s N, 29 49m 44.7985s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.4749s N, 29 49m 44.6997s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.3985s N, 29 49m 44.606s E
# [ИНФО][CONTROL] новое направление 206 (было 207)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.3192s N, 29 49m 44.5223s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.2396s N, 29 49m 44.44s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.1596s N, 29 49m 44.3587s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.0797s N, 29 49m 44.2776s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.9996s N, 29 49m 44.1967s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.9196s N, 29 49m 44.1159s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.8396s N, 29 49m 44.035s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.7596s N, 29 49m 43.9541s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 203 (было 206)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.6796s N, 29 49m 43.8732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.5996s N, 29 49m 43.7923s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.5356s N, 29 49m 43.7275s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.4538s N, 29 49m 43.654s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.3715s N, 29 49m 43.5829s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.289s N, 29 49m 43.5122s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.2066s N, 29 49m 43.4417s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.1241s N, 29 49m 43.3713s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.0416s N, 29 49m 43.301s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.9591s N, 29 49m 43.2306s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.8766s N, 29 49m 43.1602s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.7941s N, 29 49m 43.0898s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.7116s N, 29 49m 43.0194s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.6291s N, 29 49m 42.949s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.5467s N, 29 49m 42.8786s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.4642s N, 29 49m 42.8082s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.3817s N, 29 49m 42.7377s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.2992s N, 29 49m 42.6672s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 224 (было 203)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.2168s N, 29 49m 42.5967s E
# [ИНФО][CONTROL] новое направление 225 (было 224)
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.1343s N, 29 49m 42.5262s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.0519s N, 29 49m 42.4556s E
# [ИНФО][CONTROL] новое направление 226 (было 225)
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.9695s N, 29 49m 42.3849s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.9054s N, 29 49m 42.2599s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.8421s N, 29 49m 42.1332s E
# [ИНФО][CONTROL] новое направление 227 (было 226)
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.7797s N, 29 49m 42.0049s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.7182s N, 29 49m 41.8748s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.6569s N, 29 49m 41.7444s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.5956s N, 29 49m 41.6139s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.5344s N, 29 49m 41.4833s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.4732s N, 29 49m 41.3527s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.4121s N, 29 49m 41.2221s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.3509s N, 29 49m 41.0914s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.2897s N, 29 49m 40.9608s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.2285s N, 29 49m 40.8301s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.1674s N, 29 49m 40.6994s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.1184s N, 29 49m 40.5949s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.0573s N, 29 49m 40.4642s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.9961s N, 29 49m 40.3335s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.935s N, 29 49m 40.2028s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.8738s N, 29 49m 40.0721s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.8127s N, 29 49m 39.9414s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.7516s N, 29 49m 39.8106s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.6905s N, 29 49m 39.6799s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.6293s N, 29 49m 39.5491s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.5682s N, 29 49m 39.4183s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.5072s N, 29 49m 39.2875s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 167 (было 227)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.4461s N, 29 49m 39.1567s E
# [ИНФО][CONTROL] новое направление 164 (было 167)
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.3851s N, 29 49m 39.0257s E
# [ИНФО][CONTROL] новое направление 160 (было 164)
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.3241s N, 29 49m 38.8947s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.2365s N, 29 49m 38.934s E
# [ИНФО][CONTROL] новое направление 159 (было 160)
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.1502s N, 29 49m 38.983s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.0655s N, 29 49m 39.042s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.981s N, 29 49m 39.1024s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.8967s N, 29 49m 39.1636s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.8124s N, 29 49m 39.225s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.7282s N, 29 49m 39.2865s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.6608s N, 29 49m 39.3358s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.5765s N, 29 49m 39.3974s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.4923s N, 29 49m 39.459s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.408s N, 29 49m 39.5206s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.3238s N, 29 49m 39.5823s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.2396s N, 29 49m 39.6439s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 198 (было 159)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.1553s N, 29 49m 39.7056s E
# [ИНФО][CONTROL] новое направление 205 (было 198)
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.0711s N, 29 49m 39.7674s E
# [ИНФО][CONTROL] новое направление 215 (было 205)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.9869s N, 29 49m 39.8292s E
# [ИНФО][CONTROL] новое направление 221 (было 215)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.9016s N, 29 49m 39.7738s E
# [ИНФО][CONTROL] новое направление 228 (было 221)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.8207s N, 29 49m 39.6964s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 146 (было 228)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.7481s N, 29 49m 39.5915s E
# [ИНФО][CONTROL] новое направление 139 (было 146)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.681s N, 29 49m 39.4728s E
# [ИНФО][CONTROL] новое направление 132 (было 139)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.6221s N, 29 49m 39.3381s E
# [ИНФО][CONTROL] новое направление 130 (было 132)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.547s N, 29 49m 39.436s E
# [ИНФО][CONTROL] новое направление 128 (было 130)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4787s N, 29 49m 39.5517s E
# [ИНФО][CONTROL] новое направление 127 (было 128)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4183s N, 29 49m 39.6839s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3605s N, 29 49m 39.8204s E
# [ИНФО][CONTROL] новое направление 126 (было 127)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3046s N, 29 49m 39.96s E
# [ИНФО][CONTROL] новое направление 125 (было 126)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2496s N, 29 49m 40.1012s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 73 (было 125)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1954s N, 29 49m 40.2436s E
# [ИНФО][CONTROL] новое направление 69 (было 73)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1419s N, 29 49m 40.3869s E
# [ИНФО][CONTROL] новое направление 65 (было 69)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.0892s N, 29 49m 40.5313s E
# [ИНФО][CONTROL] новое направление 64 (было 65)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1147s N, 29 49m 40.7025s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1459s N, 29 49m 40.8699s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.183s N, 29 49m 41.0325s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2212s N, 29 49m 41.194s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2594s N, 29 49m 41.3556s E
# [ИНФО][CONTROL] новое направление 63 (было 64)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2983s N, 29 49m 41.5165s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3374s N, 29 49m 41.6772s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3766s N, 29 49m 41.8378s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4159s N, 29 49m 41.9983s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 88 (было 63)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4553s N, 29 49m 42.1587s E
# [ИНФО][CONTROL] новое направление 90 (было 88)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4948s N, 29 49m 42.3191s E
# [ИНФО][CONTROL] новое направление 93 (было 90)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5343s N, 29 49m 42.4794s E
# [ИНФО][CONTROL] новое направление 96 (было 93)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5739s N, 29 49m 42.6396s E
# [ИНФО][CONTROL] новое направление 97 (было 96)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5761s N, 29 49m 42.8181s E
# [ИНФО][CONTROL] новое направление 98 (было 97)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5748s N, 29 49m 42.9966s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5705s N, 29 49m 43.1392s E
# [ИНФО][CONTROL] новое направление 99 (было 98)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5613s N, 29 49m 43.3167s E
# [ИНФО][CONTROL] новое направление 100 (было 99)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5497s N, 29 49m 43.4938s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5366s N, 29 49m 43.6704s E
# [ИНФО][CONTROL] новое направление 101 (было 100)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5226s N, 29 49m 43.8467s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 114 (было 101)
# [ИНФО][CONTROL] новое направление 115 (было 114)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5077s N, 29 49m 44.0228s E
# [ИНФО][CONTROL] новое направление 116 (было 115)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4921s N, 29 49m 44.1986s E
# [ИНФО][CONTROL] новое направление 117 (было 116)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4757s N, 29 49m 44.3742s E
# [ИНФО][CONTROL] новое направление 118 (было 117)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4584s N, 29 49m 44.5494s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4213s N, 29 49m 44.712s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3828s N, 29 49m 44.8732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3425s N, 29 49m 45.0328s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3005s N, 29 49m 45.1905s E
# [ИНФО][CONTROL] новое направление 119 (было 118)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2579s N, 29 49m 45.3477s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2146s N, 29 49m 45.5041s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1712s N, 29 49m 45.6604s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1276s N, 29 49m 45.8165s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.0841s N, 29 49m 45.9725s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 142 (было 119)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.0404s N, 29 49m 46.1286s E
# [ИНФО][CONTROL] новое направление 144 (было 142)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.9968s N, 29 49m 46.2846s E
# [ИНФО][CONTROL] новое направление 146 (было 144)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.9532s N, 29 49m 46.4407s E
# [ИНФО][CONTROL] новое направление 147 (было 146)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.8821s N, 29 49m 46.5497s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.8092s N, 29 49m 46.6539s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.7343s N, 29 49m 46.7521s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.6589s N, 29 49m 46.8491s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.5984s N, 29 49m 46.9261s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.5228s N, 29 49m 47.0221s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.447s N, 29 49m 47.1179s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.3713s N, 29 49m 47.2137s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 165 (было 147)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.2955s N, 29 49m 47.3095s E
# [ИНФО][CONTROL] новое направление 167 (было 165)
# [ИНФО][CONTROL] новое направление 168 (было 167)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.2198s N, 29 49m 47.4052s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.144s N, 29 49m 47.501s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.057s N, 29 49m 47.5447s E
# [ИНФО][CONTROL] новое направление 169 (было 168)
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.97s N, 29 49m 47.5883s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.8819s N, 29 49m 47.6233s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.7938s N, 29 49m 47.6575s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.7057s N, 29 49m 47.6909s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.6175s N, 29 49m 47.7241s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.5293s N, 29 49m 47.7571s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.441s N, 29 49m 47.7901s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.3528s N, 29 49m 47.8232s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.2646s N, 29 49m 47.8562s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 190 (было 169)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.1764s N, 29 49m 47.8892s E
# [ИНФО][CONTROL] новое направление 192 (было 190)
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.0882s N, 29 49m 47.9223s E
# [ИНФО][CONTROL] новое направление 195 (было 192)
# [ИНФО][SAFETY] текущие координаты: 59 52m 28s N, 29 49m 47.9553s E
# [ИНФО][CONTROL] новое направление 196 (было 195)
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.9117s N, 29 49m 47.9235s E
# [ИНФО][CONTROL] новое направление 197 (было 196)
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.8241s N, 29 49m 47.8841s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.7378s N, 29 49m 47.8354s E
# [ИНФО][CONTROL] новое направление 198 (было 197)
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.6518s N, 29 49m 47.7841s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.5662s N, 29 49m 47.7307s E
# [ИНФО][CONTROL] маршрут пройден, текущее время 16:41:16.719776
# [ИНФО][CONTROL] новая скорость 0.0 (была 20)
# [ИНФО][CONTROL] новое направление 0 (было 198)
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.4807s N, 29 49m 47.6762s E
# [ОШИБКА][SAFETY] ошибка обработки команд: 'NoneType' object has no attribute 'longitude'
# [ИНФО][CARGO] выгрузка
# [ИНФО][CARGO] груз оставлен
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# На этом модуль 3 завершён!
#
# Если у вас всё получилось, то вы создали защищённую автономную машинку - ещё уже не так-то просто использовать для нанесения критического ущерба людям и имуществу, потому что самые критические режимы проверяются вашим Ограничителем, а если вы ещё и внедрили Монитор Безопасности, то теперь злоумышленнику гораздо сложнее атаковать внутренние блоки, даже если он смог проникнуть в какую-то бортовую систему или внедрить вредоносный код.
#
# Осталось проверить эффективность получившейся защиты на полной трассе - в этом и заключается модуль 4 задания, для перехода к которому нужно открыть блокнот с именем cyberimmunity--autonomous-car-m4. Успеха!
