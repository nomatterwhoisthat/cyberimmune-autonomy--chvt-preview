# %% [markdown]
# # Кибериммунная автономность$\\$Создание конструктивно защищённого автономного наземного транспортного средства$\\$Модуль 3
#
# ## О документе
#
# Версия 1.03
#
# Модуль 3 для регионального этапа соревнований по кибериммунной автономности

# %% [markdown]
# ### Модуль 3. Внедрение блоков функциональной и информационной безопасности
# #### Общая идея
#
# Ключевая идея кибериммунной автономности заключается в том, чтобы уже на этапе проектирования внедрить защиту от кибератак как снаружи, так и изнутри - т.е. через уязвимые бортовые информационные системы.
# Мы исходим из того, что абсолютно защищённых систем не бывает, чем больше и сложнее код, тем проще одним ("плохим") в нём спрятать уязвимости, а другим ("хорошим", но уставшим) эти уязвимости не найти.
#
# Поэтому необходимо сделать так, чтобы наиболее критичный код был отделён от некритичного и протестирован особенно тщательно - таким образом можно снизить вероятность успешной атаки и затруднить задачу атакующим.

# %% [markdown]
# #### Цели и предположения безопасности
#
# ##### Цели безопасности
# Устойчивость кибериммунных систем к атакам выражается в том, что поставленные заказчиком **цели безопасности** (ЦБ) не нарушаются даже в условиях кибератак (снаружи и изнутри).
#
# Для наших автономных машинок заказчиком поставлены следующие ЦБ:
#
# 1. При любых обстоятельствах АНТС осуществляет перемещения в пределах заданных ограничений
#
# 2. При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут
#
# 3. При любых обстоятельствах АНТС оставляет груз только в авторизованном пункте назначения
#
# Ниже используется цифро-буквенное обозначение целей безопасности - например, ЦБ1 - первая цель безопасности из списка выше.
#
# ##### Предположения безопасности
# При этом заказчик согласовал с разработчиками следующие **предположения безопасности** (ПБ) - утверждения о смежных системах, которые снимают с разработчиков часть задач для обеспечения целей безопасности:
#
# 1. При любых обстоятельствах только авторизованный персонал имеет физический доступ к критическим узлам АНТС
#
# 2. При любых обстоятельствах только аутентичные и авторизованные операторы имеют доступ к системе планирования заданий
#
# 3. Аутентичные и авторизованные операторы обладают необходимой квалификацией и являются благонадёжными (т.е. не пытаются намеренно причинить ущерб системе или третьим лицам, используя доступ к АНТС)
#
# Ниже используется цифро-буквенное обозначение предположений безопасности - например, ПБ1 - первое предположение безопасности из списка выше.

# %% [markdown]
# ### Киберпрепятствия
#
# Прежде чем мы начнём внедрять механизмы безопасности, посмотрим, что произойдёт с нашей машинкой, если бортовые системы начнут вести себя не так, как мы ожидаем.
#
# Для этого активируем специальный режим работы системы управления и снова запустим машинку по тому же маршруту, который был в конце модуля 2.
#
# После инициализации системы управления добавьте следующую строку
# ```python
# control_system.enable_surprises()
# ```

# %% [markdown]
# Но вначале нужно из модуля 2 скопировать сюда ваши текущие наработки, а именно ваши реализации классов коммуникационного шлюза (CommunicationGateway), систему навигации (NavigationSystem), управления (ControlSystem), также будем использовать маршрут, который вы создали.

# %%
# вставьте сюда ваш код
# from src.control_system import BaseControlSystem
# from src.navigation_system import BaseNavigationSystem
# from src.communication_gateway import BaseCommunicationGateway
# from multiprocessing import Queue
# from src.config import SERVOS_QUEUE_NAME
# from src.config import CONTROL_SYSTEM_QUEUE_NAME
# from src.event_types import Event
# 
# 
# class ControlSystem(BaseControlSystem):
#     """ControlSystem блок расчёта управления """
# 
#     def _send_speed_and_direction_to_consumers(self, speed, direction):
#         servos_q_name = SERVOS_QUEUE_NAME # замените на правильное название очереди
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
# 
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=BaseControlSystem.event_source_name,
#                       destination=servos_q_name,
#                       operation="set_speed", parameters=speed
#                     ) # замените на код создания сообщения со скоростью для приводов
#                            # подсказка, требуемая операция - set_speed
# 
#         # отправка сообщения с желаемым направлением
#         event_direction = Event(source=BaseControlSystem.event_source_name,
#                       destination=servos_q_name,
#                       operation="set_direction", parameters=direction
#                     ) # замените на код создания сообщения с направлением для приводов
#                                # подсказка, требуемая операция - set_direction
# 
#         servos_q.put(event_speed)
#         servos_q.put(event_direction)  
#         
# 
# 
# class CommunicationGateway(BaseCommunicationGateway):
#     """CommunicationGateway класс для реализации логики взаимодействия
#     с системой планирования заданий
# 
#     Работает в отдельном процессе, поэтому создаётся как наследник класса Process
#     """
#     def _send_mission_to_consumers(self):
#         """ метод для отправки сообщения с маршрутным заданием в систему управления """
#         
#         # имена очередей блоков находятся в файле src/config.py
#         # события нужно отправлять в соответствие с диаграммой информационных потоков
#         control_q_name = CONTROL_SYSTEM_QUEUE_NAME
# 
#         # события передаются в виде экземпляров класса Event, 
#         # описание класса находится в файле src/event_types.py
#         event = Event(source=BaseCommunicationGateway.event_source_name,
#                       destination=control_q_name,
#                       operation="set_mission", parameters=self._mission
#                       )
# 
#         # поиск в каталоге нужной очереди (в данном случае - системы управления)
#         control_q: Queue = self._queues_dir.get_queue(control_q_name)
#         # отправка события в найденную очередь
#         control_q.put(event)    
#         
# 
# 
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):        
#         control_q_name = CONTROL_SYSTEM_QUEUE_NAME # замените на правильное название очереди
#         event =  Event(source=BaseControlSystem.event_source_name,
#                       destination=control_q_name,
#                       operation="position_update", parameters=self._position
#                     ) # замените на код создания сообщения с координатами для системы управления 
#                      # подсказка, требуемая операция - position_update
#         control_q.put(event)
#         control_q: Queue = self._queues_dir.get_queue(control_q_name)

# %% [markdown]
# Если у вас настроена и работает СУПА, установите в True значение переменной afcs_present

# %%
afcs_present = True

# %% [markdown]
# Поменяем идентификатор машинки для этого модуля

# %%
car_id = "m3"

# %%
# используем то же маршрутное задание, которое было в модуле 2
# from time import sleep
# from geopy import Point as GeoPoint
# 
# 
# from src.queues_dir import QueuesDirectory
# from src.servos import Servos
# from src.sitl import SITL
# from src.cargo_bay import CargoBay
# from src.mission_planner import MissionPlanner
# from src.config import LOG_ERROR, LOG_INFO
# from src.mission_planner_mqtt import MissionSender
# from src.mission_planner import Mission
# from src.sitl_mqtt import TelemetrySender
# from src.system_wrapper import SystemComponentsContainer
# from src.wpl_parser import WPLParser
# 
# 
# # возьмём маршрут из модуля 2
# wpl_file = "module_2.wpl"
# 
# parser = WPLParser(wpl_file)    
# points = parser.parse()
# print(points)
# 
# from src.mission_type import GeoSpecificSpeedLimit
# speed_limits = [
#     GeoSpecificSpeedLimit(0, 20),
#     GeoSpecificSpeedLimit(3, 50),
#     GeoSpecificSpeedLimit(6, 20),
#     GeoSpecificSpeedLimit(8, 50),
#     GeoSpecificSpeedLimit(9, 20),
# ]
# 
# 
# home = points[0]
# mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)
# 
# # каталог очередей для передачи сообщений между блоками
# queues_dir = QueuesDirectory() 
# 
# if afcs_present:
#     mission_sender = MissionSender(
#         queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
#     telemetry_sender = TelemetrySender(
#         queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
# 
# mission_planner = MissionPlanner(
#     queues_dir, afcs_present=afcs_present, mission=mission)
# 
# sitl = SITL(
#     queues_dir=queues_dir, position=home,
#     car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)
# 
# communication_gateway = CommunicationGateway(
#     queues_dir=queues_dir, log_level=LOG_ERROR)
# control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)
# 
# navigation_system = NavigationSystem(
#     queues_dir=queues_dir, log_level=LOG_ERROR)
# 
# servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
# cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)
# 
# # по аналогии собираем все блоки в одном кузове
# system_components = SystemComponentsContainer(
#     components=[
#         mission_sender,
#         telemetry_sender,
#         sitl,
#         mission_planner,
#         navigation_system,
#         servos,
#         cargo_bay,
#         communication_gateway,
#         control_system
#     ] if afcs_present else [
#         sitl,
#         mission_planner,
#         navigation_system,
#         servos,
#         cargo_bay,
#         communication_gateway,
#         control_system
#     ])
# 
# #################################
# # АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
# control_system.enable_surprises()
# #################################
# 
# # system_components.start()
# 
# # ограничение поездки по времени
# # параметр sleep - время в секундах,
# # настройте этот параметр так, чтобы ваша машинка завершила маршрут
# # в случае превышения времени выполнения ячейки на более чем 10 секунд от заданного, 
# # допустимо перезапустить вычислительное ядро и повторно выполнить весь блокнот, штрафные очки за это не начисляются
# # при условии, что повторный запуск закончился успешно
# # sleep(10)
# 
# # останавливаем все компоненты
# # system_components.stop()
# 
# # удалим все созданные компоненты
# # system_components.clean()
# del system_components

# %% [markdown]
# Итак, в отличие от, надеемся, успешного завершения маршрута в модуле 2, сейчас ваша машинка ведёт себя совсем иначе. Например, она внезапно едет в совершенно другую сторону (это особенно хорошо видно при использовании СУПА).
# И это ещё не всё, что может пойти не так..
#
# В этой реализации не очень много кода, теоретически, вы можете его весь изучить и устранить "незадокументированные возможности", однако в реальных системах кода гораздо больше. Например, кодовая база проекта с открытым исходным кодом ArduPilot, реализующего в том числе логику автопилота, составляет примерно миллион строк.
#
# Сколько времени вам понадобится, чтобы изучить и протестировать миллион строк кода? А ведь придётся проводить анализ и каждого обновления.. При этом неприятности могут быть хорошо спрятанными и на первый взгляд безобидными, вряд ли злоумышленники облегчат задачу и назовут свои изменения, например, "hacking_the_system" или "allowing_secret_remote_access". Вредоносный код может выглядеть совершенно безобидно или маскироваться под программный дефект.
#
# Поэтому тщательный анализ потребует большого количества ресурсов (человеческих, вычислительных, временных), что стоит дорого.
#
# Логичным выходом является выделение критичных для целей безопасности проверок в отдельный блок, который протестировать должно быть гораздо проще.

# %% [markdown]
# #### Задания
#
# В этом модуле задание будет состоять из двух частей разной сложности:
#
# **3.1. добавить новый блок - "Ограничитель"** - этот модуль должен будет обеспечить соблюдение ограничений, указанных в маршрутном задании - это необходимо для обеспечения ЦБ1
#
# **З.2. *(задание повышенной сложности)* добавить монитор безопасности (МБ)** - он должен контролировать все взаимодействия *бортовых систем* (т.е. не включая планировщик и симулятор) и не давать блокам взаимодействовать друг с другом непредусмотренным образом - например, блок №5 может принимать команды только от №3, попытка передать команду в №5 от №2 должна блокироваться нашим монитором безопасности - потенциально это необходимо для обеспечения всех ЦБ

# %% [markdown]
# Для выполнения первой части задачи 3.1. необходимо для начала изменить архитектуру АНТС как показано на рис. 5
#
# ![Архитектура системы с ограничителем](images/ciac-arch-m31.png)
#
# Рис. 5. Архитектура АНТС с ограничителем (для ЦБ1)

# %% [markdown]
# Код базового класса Ограничителя находится в файле src/safety_block.py
#
# По аналогии с заданием в модуле 1, необходимо создать на основе этого класса свой собственный под названием SafetyBlock, в котором реализовать передачу команд в приводы движения, только перед эти необходимо ещё и проконтролировать их безопасность.
#
# Также необходимо реализовать передачу маршрутного задания из CommunicationGateway в SafetyBlock и координат из модуля Navigation в соответствии со стрелками на рис.5 выше.
#
# Если всё сделано правильно, то Ограничителю будет известно следующее
#
# - _mission - текущее маршрутное задание
# - _position - текущие координаты
#
# После проверки нужно установить значение внутренних переменных
# - _speed - текущая (допустимая) скорость
# - _direction - текущее (допустимое) направление
#
# Желательно завершить следование по маршруту. В критической ситуации, если продолжение маршрута невозможно, следует установить значение скорости и направления в 0, после чего передать эти команды в блок приводов (Servos)

# %% [markdown]
# Базовый сценарий для новой архитектуры можно представить следующим образом (см. рис. 6)
#
# ![Базовый сценарий с блоком безопасности](images/basic-scenario-with-safety-block1.png)
#
# Рис. 6. Базовый сценарий с блоком безопасности

# %% [markdown]
# Заготовка кода SafetyBlock
#
# ```python
# class SafetyBlock(BaseSafetyBlock):
#     """ класс ограничений безопасности """
#
#     def _set_new_direction(self, direction: float):
#         """ установка нового направления перемещения """
#         self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
#         self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
#         self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
#         # TODO реализовать контроль безопасности изменения направления
#         self._direction = direction
#         self._send_direction_to_consumers()
#
#     def _set_new_speed(self, speed: float):
#         """ установка новой скорости """
#         # TODO реализовать контроль безопасности изменения скорости
#         self._speed = speed
#         self._send_speed_to_consumers()
#
#
#     def _send_speed_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем скорость получателям")
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_speed",
#                             parameters=self._speed
#                             )
#         servos_q.put(event_speed)
#
#     def _send_direction_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем направление получателям")
#
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_direction",
#                             parameters=self._direction
#                             )
#         servos_q.put(event_speed)
# ```

# %%
from src.safety_block import BaseSafetyBlock
from src.config import *
import math
from time import sleep
from geopy import Point as GeoPoint
from src.config import LOG_ERROR, LOG_INFO, LOG_DEBUG
from multiprocessing import Queue
from src.config import SERVOS_QUEUE_NAME
from src.event_types import Event


class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        # TODO реализовать контроль безопасности изменения направления

        if not self._position or not self._route:
            return
        
        current = self._position
        next = self._route.next_point()
        bearing = self._calculate_bearing(current, next)
        
        direction = max(bearing - 5, min(bearing + 5, direction))
                
        self._direction = direction
        # отправка сообщения с желаемым направлением
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        if not self._route:
            return

        speed = max(0, min(speed, self._route.calculate_speed()))

        self._speed = speed
        self._send_speed_to_consumers()

    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        servos_q.put(event_speed)

    def _lock_cargo(self, _):
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._send_lock_cargo_to_consumers()

    def _send_lock_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду блокировки в CargoBay")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="lock_cargo",
            parameters=None
        )
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        cargo_q.put(event)
        
    def _release_cargo(self, _):
        if not self._route or not self._route.route_finished:
            return
        self._send_release_cargo_to_consumers()

    def _send_release_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду выгрузки в CargoBay")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="release_cargo",
            parameters=None
        )
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        cargo_q.put(event)

    def _calculate_bearing(self, start: GeoPoint, end: GeoPoint):
        delta_longitude = end.longitude - start.longitude
        x = math.sin(math.radians(delta_longitude)) * \
            math.cos(math.radians(end.latitude))
        y = math.cos(math.radians(start.latitude)) * math.sin(math.radians(end.latitude)) - \
            math.sin(math.radians(start.latitude)) * math.cos(math.radians(end.latitude)) * \
            math.cos(math.radians(delta_longitude))
        initial_bearing_rad = math.atan2(x, y)

        # Преобразуем радианы в градусы
        initial_bearing_deg = math.degrees(initial_bearing_rad)

        # Нормализуем значение в диапазоне [0, 360]
        compass_bearing = (initial_bearing_deg + 360) % 360

        return compass_bearing

# %%
# 2. напишите в этом блоке реализацию изменённых блоков связи, управления и навигации, 
# чтобы передавать данные согласно изменённой архитектуре на рис. 5 для обеспечения работы по сценарию на рис.6

# вставьте сюда ваш код
from src.control_system import BaseControlSystem
from src.navigation_system import BaseNavigationSystem
from src.communication_gateway import BaseCommunicationGateway
from multiprocessing import Queue
from src.config import SAFETY_BLOCK_QUEUE_NAME
from src.config import SERVOS_QUEUE_NAME
from src.config import CONTROL_SYSTEM_QUEUE_NAME
from src.event_types import Event


class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_speed", parameters=speed
                    ) # замените на код создания сообщения со скоростью для приводов
                           # подсказка, требуемая операция - set_speed

        # отправка сообщения с желаемым направлением
        event_direction = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_direction", parameters=direction
                    ) # замените на код создания сообщения с направлением для приводов
                               # подсказка, требуемая операция - set_direction

        safety_q.put(event_speed)
        safety_q.put(event_direction)  
        
    def _lock_cargo(self):
        """ заблокировать грузовой отсек """
        safety_q = self._queues_dir.get_queue(SAFETY_BLOCK_QUEUE_NAME)
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                    destination=SAFETY_BLOCK_QUEUE_NAME,
                    operation="lock_cargo", parameters= None
                    )
        safety_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """
        safety_q = self._queues_dir.get_queue(SAFETY_BLOCK_QUEUE_NAME)
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME, 
                    destination=SAFETY_BLOCK_QUEUE_NAME,
                    operation="release_cargo", parameters= None
                    )  
        safety_q.put(event)      


class CommunicationGateway(BaseCommunicationGateway):
    """CommunicationGateway класс для реализации логики взаимодействия
    с системой планирования заданий

    Работает в отдельном процессе, поэтому создаётся как наследник класса Process
    """
    def _send_mission_to_consumers(self):
        """ метод для отправки сообщения с маршрутным заданием в систему управления """
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)
                
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)


class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):        
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="position_update", parameters=self._position
                      )
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)
      
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        event =  Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="position_update", parameters=self._position
                    ) # замените на код создания сообщения с координатами для системы управления 
                     # подсказка, требуемая операция - position_update
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)

# %%
# создадим все остальные компоненты

# используем то же маршрутное задание, которое было в модуле 2
from time import sleep
from geopy import Point as GeoPoint


from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser


# возьмём маршрут из модуля 2
wpl_file = "module_2.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()
print(points)

from src.mission_type import GeoSpecificSpeedLimit
speed_limits = [
    GeoSpecificSpeedLimit(0, 20),
    GeoSpecificSpeedLimit(3, 50),
    GeoSpecificSpeedLimit(6, 20),
    GeoSpecificSpeedLimit(8, 40),
    GeoSpecificSpeedLimit(9, 20),
]


home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
################################

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)


system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ])

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(210)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()

del system_components
# Out:
# [Point(59.8815191, 29.8300481, 0.0), Point(59.8819121, 29.8282993, 0.0), Point(59.8818098, 29.8277092, 0.0), Point(59.8818583, 29.8274088, 0.0), Point(59.8810884, 29.8267436, 0.0), Point(59.8796617, 29.8254454, 0.0), Point(59.8785849, 29.8245013, 0.0), Point(59.8781972, 29.8241472, 0.0), Point(59.8781003, 29.8241258, 0.0), Point(59.8780249, 29.8242867, 0.0), Point(59.8774811, 29.8267651, 0.0), Point(59.8769158, 29.8291469, 0.0), Point(59.8768512, 29.8291361, 0.0), Point(59.8765389, 29.8288143, 0.0), Point(59.8761512, 29.8284817, 0.0), Point(59.8756531, 29.8274866, 0.0), Point(59.8752903, 29.8277186, 0.0), Point(59.8751927, 29.8276126, 0.0), Point(59.875042, 29.8278809, 0.0), Point(59.8751443, 29.8284495, 0.0), Point(59.8751335, 29.8289645, 0.0), Point(59.8749935, 29.8295438, 0.0), Point(59.8747674, 29.829855, 0.0), Point(59.874455, 29.8299837, 0.0), Point(59.8742666, 29.8298872, 0.0)]
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CONTROL] старт системы управления[ИНФО][CARGO] старт блока грузового отсека
#
# [ИНФО][SAFETY] старт ограничителя[ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
#
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 23:33:37.421096
# [ИНФО][SAFETY] Блокировка грузового отсека
# [ИНФО][CONTROL] новая скорость 20 (была 0)
# [ИНФО][CONTROL] новое направление 294 (было 0)
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4688s N, 29 49m 48.1732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4688s N, 29 49m 48.1732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4688s N, 29 49m 48.1732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4981s N, 29 49m 48.0428s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.5348s N, 29 49m 47.8798s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.5715s N, 29 49m 47.7168s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.6082s N, 29 49m 47.5539s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.6449s N, 29 49m 47.3909s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.6815s N, 29 49m 47.2279s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7182s N, 29 49m 47.0649s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7549s N, 29 49m 46.9019s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7916s N, 29 49m 46.739s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.8283s N, 29 49m 46.576s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.8649s N, 29 49m 46.413s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.9016s N, 29 49m 46.25s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.9383s N, 29 49m 46.087s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.975s N, 29 49m 45.924s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.0116s N, 29 49m 45.761s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.0483s N, 29 49m 45.598s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.0849s N, 29 49m 45.435s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1216s N, 29 49m 45.272s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1583s N, 29 49m 45.109s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1876s N, 29 49m 44.9786s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.2242s N, 29 49m 44.8156s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.2609s N, 29 49m 44.6526s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.2975s N, 29 49m 44.4896s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3342s N, 29 49m 44.3266s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3708s N, 29 49m 44.1635s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4075s N, 29 49m 44.0005s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4441s N, 29 49m 43.8375s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4807s N, 29 49m 43.6745s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5173s N, 29 49m 43.5114s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.554s N, 29 49m 43.3484s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5906s N, 29 49m 43.1854s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6272s N, 29 49m 43.0223s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6638s N, 29 49m 42.8593s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7004s N, 29 49m 42.6962s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.737s N, 29 49m 42.5331s E
# [ИНФО][CONTROL] новое направление 293 (было 294)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7736s N, 29 49m 42.3701s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8101s N, 29 49m 42.207s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 73 (было 293)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8467s N, 29 49m 42.0439s E
# [ИНФО][CONTROL] новое направление 70 (было 73)
# [ИНФО][CONTROL] новое направление 67 (было 70)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8832s N, 29 49m 41.8808s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.9197s N, 29 49m 41.7176s E
# [ИНФО][CONTROL] новое направление 64 (было 67)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.9488s N, 29 49m 41.5871s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.9166s N, 29 49m 41.4204s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8754s N, 29 49m 41.2618s E
# [ИНФО][CONTROL] новое направление 65 (было 64)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8302s N, 29 49m 41.1075s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7845s N, 29 49m 40.9538s E
# [ИНФО][CONTROL] новое направление 66 (было 65)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.739s N, 29 49m 40.7998s E
# [ИНФО][CONTROL] новое направление 68 (было 66)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6943s N, 29 49m 40.645s E
# [ИНФО][CONTROL] новое направление 69 (было 68)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6507s N, 29 49m 40.4889s E
# [ИНФО][CONTROL] новое направление 72 (было 69)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6085s N, 29 49m 40.3313s E
# [ИНФО][CONTROL] новое направление 75 (было 72)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.568s N, 29 49m 40.1719s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 120 (была 20)
# [ИНФО][CONTROL] новое направление 283 (было 75)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5298s N, 29 49m 40.0103s E
# [ИНФО][CONTROL] новое направление 288 (было 283)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4951s N, 29 49m 39.8457s E
# [ИНФО][CONTROL] новое направление 293 (было 288)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4657s N, 29 49m 39.6769s E
# [ИНФО][CONTROL] новое направление 295 (было 293)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4865s N, 29 49m 39.5032s E
# [ИНФО][CONTROL] новое направление 297 (было 295)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5147s N, 29 49m 39.3336s E
# [ИНФО][CONTROL] новое направление 298 (было 297)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5512s N, 29 49m 39.1705s E
# [ИНФО][CONTROL] новое направление 300 (было 298)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5905s N, 29 49m 39.0099s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 50 (была 120)
# [ИНФО][CONTROL] новое направление 205 (было 300)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6324s N, 29 49m 38.852s E
# [ИНФО][CONTROL] новое направление 203 (было 205)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6759s N, 29 49m 38.6958s E
# [ИНФО][CONTROL] новое направление 202 (было 203)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7212s N, 29 49m 38.5417s E
# [ИНФО][CONTROL] новое направление 201 (было 202)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5186s N, 29 49m 38.3498s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3132s N, 29 49m 38.1699s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1052s N, 29 49m 38.0026s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.8968s N, 29 49m 37.837s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7299s N, 29 49m 37.7054s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.5213s N, 29 49m 37.541s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.3126s N, 29 49m 37.3768s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.104s N, 29 49m 37.2125s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.8953s N, 29 49m 37.0483s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.6867s N, 29 49m 36.884s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.478s N, 29 49m 36.7196s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.2694s N, 29 49m 36.5552s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 204 (было 201)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.0608s N, 29 49m 36.3907s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.8522s N, 29 49m 36.2261s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.6437s N, 29 49m 36.0611s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.4352s N, 29 49m 35.8962s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.231s N, 29 49m 35.7113s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.0269s N, 29 49m 35.5255s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.8231s N, 29 49m 35.3389s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.6194s N, 29 49m 35.1514s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.4158s N, 29 49m 34.9637s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.2123s N, 29 49m 34.7759s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.0087s N, 29 49m 34.588s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.8051s N, 29 49m 34.4001s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.6016s N, 29 49m 34.2122s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.3981s N, 29 49m 34.0243s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.2352s N, 29 49m 33.8739s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.0317s N, 29 49m 33.6859s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.8282s N, 29 49m 33.4979s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.6247s N, 29 49m 33.3098s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.4212s N, 29 49m 33.1218s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.2176s N, 29 49m 32.9337s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.0142s N, 29 49m 32.7455s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.8107s N, 29 49m 32.5573s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.6072s N, 29 49m 32.3691s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.4037s N, 29 49m 32.1808s E
# [ИНФО][CONTROL] новое направление 205 (было 204)
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.2003s N, 29 49m 31.9925s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.9969s N, 29 49m 31.804s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 203 (было 205)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.7935s N, 29 49m 31.6154s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.5902s N, 29 49m 31.4266s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.387s N, 29 49m 31.2371s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.1816s N, 29 49m 31.0573s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.9761s N, 29 49m 30.8779s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.7705s N, 29 49m 30.6991s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.5649s N, 29 49m 30.5203s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.3593s N, 29 49m 30.3416s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.1536s N, 29 49m 30.1629s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.948s N, 29 49m 29.9841s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.7424s N, 29 49m 29.8053s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.5368s N, 29 49m 29.6265s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.3723s N, 29 49m 29.4835s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.1667s N, 29 49m 29.3046s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.9611s N, 29 49m 29.1257s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.7555s N, 29 49m 28.9468s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.55s N, 29 49m 28.7678s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.3444s N, 29 49m 28.5887s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.1389s N, 29 49m 28.4095s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 50)
# [ИНФО][CONTROL] новое направление 204 (было 203)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.9334s N, 29 49m 28.2304s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.7279s N, 29 49m 28.0511s E
# [ИНФО][CONTROL] новое направление 205 (было 204)
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.5224s N, 29 49m 27.8716s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.3171s N, 29 49m 27.6916s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.2355s N, 29 49m 27.6172s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.154s N, 29 49m 27.5423s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.0729s N, 29 49m 27.4659s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.9918s N, 29 49m 27.3892s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.9108s N, 29 49m 27.3123s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.8298s N, 29 49m 27.2353s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.7488s N, 29 49m 27.1583s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.6679s N, 29 49m 27.0812s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 190 (было 205)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.5869s N, 29 49m 27.004s E
# [ИНФО][CONTROL] новое направление 186 (было 190)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.506s N, 29 49m 26.9268s E
# [ИНФО][CONTROL] новое направление 180 (было 186)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.4236s N, 29 49m 26.8586s E
# [ИНФО][CONTROL] новое направление 177 (было 180)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.3529s N, 29 49m 26.8336s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 40 (была 20)
# [ИНФО][CONTROL] новое направление 140 (было 177)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.2637s N, 29 49m 26.8145s E
# [ИНФО][CONTROL] новое направление 132 (было 140)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.1739s N, 29 49m 26.8125s E
# [ИНФО][CONTROL] новое направление 122 (было 132)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.0843s N, 29 49m 26.8215s E
# [ИНФО][CONTROL] новое направление 106 (было 122)
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.9461s N, 29 49m 27.0494s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 40)
# [ИНФО][CONTROL] новое направление 112 (было 106)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.8249s N, 29 49m 27.313s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.7287s N, 29 49m 27.6144s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.6781s N, 29 49m 27.957s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.6435s N, 29 49m 28.1218s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.6095s N, 29 49m 28.287s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.5751s N, 29 49m 28.452s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.5408s N, 29 49m 28.617s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.5064s N, 29 49m 28.7819s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.4721s N, 29 49m 28.9469s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.4377s N, 29 49m 29.1118s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.4034s N, 29 49m 29.2768s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.369s N, 29 49m 29.4417s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.3347s N, 29 49m 29.6067s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.3003s N, 29 49m 29.7717s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.266s N, 29 49m 29.9366s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.2316s N, 29 49m 30.1016s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.1973s N, 29 49m 30.2665s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.1629s N, 29 49m 30.4315s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.1286s N, 29 49m 30.5965s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.0942s N, 29 49m 30.7614s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.0668s N, 29 49m 30.8934s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.0324s N, 29 49m 31.0584s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.9981s N, 29 49m 31.2234s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.9637s N, 29 49m 31.3883s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.9294s N, 29 49m 31.5533s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.8951s N, 29 49m 31.7183s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.8607s N, 29 49m 31.8832s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.8264s N, 29 49m 32.0482s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.7921s N, 29 49m 32.2132s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.7577s N, 29 49m 32.3782s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.7234s N, 29 49m 32.5432s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.6891s N, 29 49m 32.7081s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.6548s N, 29 49m 32.8731s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.6204s N, 29 49m 33.0381s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.5861s N, 29 49m 33.2031s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.5518s N, 29 49m 33.3681s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.5175s N, 29 49m 33.5331s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.4832s N, 29 49m 33.6981s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.4489s N, 29 49m 33.8631s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.4146s N, 29 49m 34.0281s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.3803s N, 29 49m 34.1931s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.346s N, 29 49m 34.3581s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.3117s N, 29 49m 34.5231s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2774s N, 29 49m 34.6881s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.25s N, 29 49m 34.8201s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2157s N, 29 49m 34.9851s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.1814s N, 29 49m 35.1502s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.1472s N, 29 49m 35.3152s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.1129s N, 29 49m 35.4802s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.0787s N, 29 49m 35.6453s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.0444s N, 29 49m 35.8103s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.0102s N, 29 49m 35.9754s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 115 (было 112)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.976s N, 29 49m 36.1404s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.9418s N, 29 49m 36.3055s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.9077s N, 29 49m 36.4707s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.8694s N, 29 49m 36.6322s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.831s N, 29 49m 36.7936s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7926s N, 29 49m 36.955s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7542s N, 29 49m 37.1163s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7158s N, 29 49m 37.2777s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.6773s N, 29 49m 37.4391s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.6389s N, 29 49m 37.6004s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.6005s N, 29 49m 37.7618s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.5621s N, 29 49m 37.9232s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.5236s N, 29 49m 38.0845s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4852s N, 29 49m 38.2459s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4468s N, 29 49m 38.4073s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4084s N, 29 49m 38.5686s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.37s N, 29 49m 38.73s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.3316s N, 29 49m 38.8914s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.2931s N, 29 49m 39.0527s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.2624s N, 29 49m 39.1818s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.224s N, 29 49m 39.3432s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.1856s N, 29 49m 39.5046s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.1472s N, 29 49m 39.666s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.1088s N, 29 49m 39.8273s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.0704s N, 29 49m 39.9887s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.032s N, 29 49m 40.1501s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9936s N, 29 49m 40.3115s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9552s N, 29 49m 40.4729s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9168s N, 29 49m 40.6343s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.8784s N, 29 49m 40.7956s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.84s N, 29 49m 40.957s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.8016s N, 29 49m 41.1184s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.7632s N, 29 49m 41.2798s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.7248s N, 29 49m 41.4412s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.6864s N, 29 49m 41.6026s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.648s N, 29 49m 41.764s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.6097s N, 29 49m 41.9254s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.5713s N, 29 49m 42.0868s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.5329s N, 29 49m 42.2482s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.4945s N, 29 49m 42.4097s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.4562s N, 29 49m 42.5711s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.4178s N, 29 49m 42.7325s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.3871s N, 29 49m 42.8616s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.3488s N, 29 49m 43.0231s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.3104s N, 29 49m 43.1845s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.2721s N, 29 49m 43.3459s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.2337s N, 29 49m 43.5074s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.1954s N, 29 49m 43.6688s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.157s N, 29 49m 43.8303s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.1187s N, 29 49m 43.9917s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.0804s N, 29 49m 44.1532s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.0421s N, 29 49m 44.3147s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.0038s N, 29 49m 44.4761s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 157 (было 115)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.9655s N, 29 49m 44.6376s E
# [ИНФО][CONTROL] новое направление 170 (было 157)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.9273s N, 29 49m 44.7992s E
# [ИНФО][CONTROL] новое направление 186 (было 170)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.8802s N, 29 49m 44.9422s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 206 (было 186)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.7963s N, 29 49m 45.0037s E
# [ИНФО][CONTROL] новое направление 209 (было 206)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.7077s N, 29 49m 45.0238s E
# [ИНФО][CONTROL] новое направление 210 (было 209)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.6204s N, 29 49m 44.9904s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.5407s N, 29 49m 44.9083s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.4624s N, 29 49m 44.8209s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.385s N, 29 49m 44.7307s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.3077s N, 29 49m 44.6399s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.2305s N, 29 49m 44.5488s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.1533s N, 29 49m 44.4577s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.0916s N, 29 49m 44.3847s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.0144s N, 29 49m 44.2935s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.9372s N, 29 49m 44.2023s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.8601s N, 29 49m 44.1111s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.7829s N, 29 49m 44.0199s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.7058s N, 29 49m 43.9286s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 203 (было 210)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.6286s N, 29 49m 43.8373s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.5515s N, 29 49m 43.746s E
# [ИНФО][CONTROL] новое направление 202 (было 203)
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.4744s N, 29 49m 43.6546s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.3973s N, 29 49m 43.5631s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.3151s N, 29 49m 43.4913s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.2327s N, 29 49m 43.4208s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.15s N, 29 49m 43.3516s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.0669s N, 29 49m 43.2838s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.9838s N, 29 49m 43.2163s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.9007s N, 29 49m 43.1489s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.8176s N, 29 49m 43.0814s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.7345s N, 29 49m 43.014s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.6514s N, 29 49m 42.9466s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.5683s N, 29 49m 42.8791s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.4852s N, 29 49m 42.8117s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.4021s N, 29 49m 42.7442s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.319s N, 29 49m 42.6767s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 224 (было 202)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.2525s N, 29 49m 42.6226s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.1694s N, 29 49m 42.555s E
# [ИНФО][CONTROL] новое направление 225 (было 224)
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.0864s N, 29 49m 42.4874s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.0219s N, 29 49m 42.3631s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.9583s N, 29 49m 42.2372s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.8955s N, 29 49m 42.1096s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.8328s N, 29 49m 41.9818s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.7702s N, 29 49m 41.8539s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.7075s N, 29 49m 41.726s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.6449s N, 29 49m 41.5982s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.5823s N, 29 49m 41.4703s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.5196s N, 29 49m 41.3424s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.457s N, 29 49m 41.2145s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.3944s N, 29 49m 41.0866s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.3317s N, 29 49m 40.9587s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.2691s N, 29 49m 40.8307s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.2065s N, 29 49m 40.7028s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.1439s N, 29 49m 40.5749s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.0813s N, 29 49m 40.447s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.0187s N, 29 49m 40.319s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.9561s N, 29 49m 40.191s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.906s N, 29 49m 40.0887s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.8434s N, 29 49m 39.9607s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.7808s N, 29 49m 39.8327s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.7183s N, 29 49m 39.7047s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.6557s N, 29 49m 39.5767s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.5931s N, 29 49m 39.4487s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.5306s N, 29 49m 39.3206s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.468s N, 29 49m 39.1926s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 165 (было 225)
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.4055s N, 29 49m 39.0645s E
# [ИНФО][CONTROL] новое направление 161 (было 165)
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.343s N, 29 49m 38.9363s E
# [ИНФО][CONTROL] новое направление 158 (было 161)
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.2805s N, 29 49m 38.8081s E
# [ИНФО][CONTROL] новое направление 155 (было 158)
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.2133s N, 29 49m 38.7146s E
# [ИНФО][CONTROL] новое направление 154 (было 155)
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.1268s N, 29 49m 38.7626s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.042s N, 29 49m 38.8204s E
# [ИНФО][CONTROL] новое направление 153 (было 154)
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.9589s N, 29 49m 38.8881s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.8775s N, 29 49m 38.9632s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.7965s N, 29 49m 39.0401s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.7158s N, 29 49m 39.1184s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.6354s N, 29 49m 39.1976s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.555s N, 29 49m 39.2771s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.4747s N, 29 49m 39.357s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.3945s N, 29 49m 39.437s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.3143s N, 29 49m 39.5171s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.2341s N, 29 49m 39.5972s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 195 (было 153)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.1699s N, 29 49m 39.6614s E
# [ИНФО][CONTROL] новое направление 203 (было 195)
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.0897s N, 29 49m 39.7416s E
# [ИНФО][CONTROL] новое направление 213 (было 203)
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.0096s N, 29 49m 39.822s E
# [ИНФО][CONTROL] новое направление 219 (было 213)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.9229s N, 29 49m 39.7755s E
# [ИНФО][CONTROL] новое направление 225 (было 219)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.8403s N, 29 49m 39.7055s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 148 (было 225)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.7655s N, 29 49m 39.6069s E
# [ИНФО][CONTROL] новое направление 141 (было 148)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.6958s N, 29 49m 39.4945s E
# [ИНФО][CONTROL] новое направление 134 (было 141)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.6304s N, 29 49m 39.4111s E
# [ИНФО][CONTROL] новое направление 133 (было 134)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5556s N, 29 49m 39.5092s E
# [ИНФО][CONTROL] новое направление 131 (было 133)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4871s N, 29 49m 39.6242s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4242s N, 29 49m 39.7516s E
# [ИНФО][CONTROL] новое направление 130 (было 131)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3632s N, 29 49m 39.8826s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3034s N, 29 49m 40.0158s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 76 (было 130)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2443s N, 29 49m 40.1501s E
# [ИНФО][CONTROL] новое направление 72 (было 76)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1857s N, 29 49m 40.2854s E
# [ИНФО][CONTROL] новое направление 69 (было 72)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1433s N, 29 49m 40.4287s E
# [ИНФО][CONTROL] новое направление 68 (было 69)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1655s N, 29 49m 40.6017s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1932s N, 29 49m 40.7714s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.225s N, 29 49m 40.9384s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2575s N, 29 49m 41.1048s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2901s N, 29 49m 41.2712s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3231s N, 29 49m 41.4372s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3562s N, 29 49m 41.6032s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3827s N, 29 49m 41.7359s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4159s N, 29 49m 41.9018s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4492s N, 29 49m 42.0676s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 90 (было 68)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4825s N, 29 49m 42.2334s E
# [ИНФО][CONTROL] новое направление 92 (было 90)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5158s N, 29 49m 42.3992s E
# [ИНФО][CONTROL] новое направление 94 (было 92)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5491s N, 29 49m 42.565s E
# [ИНФО][CONTROL] новое направление 97 (было 94)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5824s N, 29 49m 42.7308s E[ИНФО][CONTROL] новое направление 98 (было 97)
#
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5822s N, 29 49m 42.9094s E
# [ИНФО][CONTROL] новое направление 99 (было 98)
# [ИНФО][CONTROL] новое направление 100 (было 99)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5788s N, 29 49m 43.0878s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5708s N, 29 49m 43.2655s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5588s N, 29 49m 43.4425s E
# [ИНФО][CONTROL] новое направление 101 (было 100)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5451s N, 29 49m 43.6189s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5291s N, 29 49m 43.7946s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 114 (было 101)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5124s N, 29 49m 43.97s E
# [ИНФО][CONTROL] новое направление 115 (было 114)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.495s N, 29 49m 44.1452s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4734s N, 29 49m 44.3178s E
# [ИНФО][CONTROL] новое направление 116 (было 115)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4365s N, 29 49m 44.4805s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3983s N, 29 49m 44.6421s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3591s N, 29 49m 44.8026s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3197s N, 29 49m 44.9631s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2802s N, 29 49m 45.1234s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2407s N, 29 49m 45.2837s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2012s N, 29 49m 45.444s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1617s N, 29 49m 45.6044s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1301s N, 29 49m 45.7326s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.0906s N, 29 49m 45.893s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.0512s N, 29 49m 46.0533s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 143 (было 116)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.0117s N, 29 49m 46.2137s E
# [ИНФО][CONTROL] новое направление 145 (было 143)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.9723s N, 29 49m 46.3741s E
# [ИНФО][CONTROL] новое направление 148 (было 145)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.9329s N, 29 49m 46.5345s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.861s N, 29 49m 46.6414s E
# [ИНФО][CONTROL] новое направление 149 (было 148)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.7869s N, 29 49m 46.7422s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.7105s N, 29 49m 46.8357s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.6335s N, 29 49m 46.9275s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.5562s N, 29 49m 47.0183s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.4788s N, 29 49m 47.1088s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.4014s N, 29 49m 47.1992s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.324s N, 29 49m 47.2895s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 166 (было 149)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.2465s N, 29 49m 47.3797s E
# [ИНФО][CONTROL] новое направление 168 (было 166)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.1691s N, 29 49m 47.47s E
# [ИНФО][CONTROL] новое направление 169 (было 168)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.0897s N, 29 49m 47.5504s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.0022s N, 29 49m 47.5901s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.9142s N, 29 49m 47.6259s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.826s N, 29 49m 47.6587s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.7378s N, 29 49m 47.6913s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.6495s N, 29 49m 47.7233s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.5611s N, 29 49m 47.755s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.4728s N, 29 49m 47.7866s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.3844s N, 29 49m 47.8181s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.2961s N, 29 49m 47.8496s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.2077s N, 29 49m 47.881s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 191 (было 169)
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.1194s N, 29 49m 47.9124s E
# [ИНФО][CONTROL] новое направление 194 (было 191)
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.031s N, 29 49m 47.9437s E
# [ИНФО][CONTROL] новое направление 198 (было 194)
# [ИНФО][CONTROL] новое направление 202 (было 198)
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.9426s N, 29 49m 47.9751s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.8544s N, 29 49m 47.9928s E
# [ИНФО][CONTROL] новое направление 203 (было 202)
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.7841s N, 29 49m 47.9634s E
# [ИНФО][CONTROL] новое направление 205 (было 203)
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.6973s N, 29 49m 47.9182s E
# [ИНФО][CONTROL] новое направление 206 (было 205)
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.6141s N, 29 49m 47.8512s E
# [ИНФО][CONTROL] новое направление 208 (было 206)
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.5321s N, 29 49m 47.7785s E
# [ИНФО][CONTROL] маршрут пройден, текущее время 23:37:14.869115
# [ИНФО][CONTROL] новая скорость 0.0 (была 20)
# [ИНФО][CONTROL] новое направление 0 (было 208)
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.4514s N, 29 49m 47.7003s E
# [ОШИБКА][SAFETY] ошибка обработки команд: 'NoneType' object has no attribute 'longitude'
# [ИНФО][CARGO] выгрузка
# [ИНФО][CARGO] груз оставлен
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# #### Обеспечение ЦБ3: контроль доставки груза
#
# С помощью логики ограничителя выше мы реализовали обеспечение ЦБ1 (соблюдение заданных ограничений), однако есть ещё ЦБ3 (отгрузка только в заданной точке), не говоря о ЦБ2 (следование только по аутентичному маршруту).
#
# Для обеспечения ЦБ3 необходимо сделать следующее
# 1. изменить последовательность передачи команд, чтобы в блок управления грузовым отсеком (CargoBay) команды приходили только после проверки в Ограничителе
# 2. доработайте реализацию Ограничителя, чтобы команда на выгрузку передавалась в CargoBay только в конечной точке маршрута
# 3. продумайте логику работы блока безопасности, если система управления полностью перестанет работать (т.е. перестанет отправлять новые команды).
#
# Изменённая архитектура приведена на рис. 7.
#
# ![Ограничитель для обеспечения ЦБ1 и ЦБ3](images/ciac-arch-m312.png)
#
# Рис. 7. Ограничитель для обеспечения ЦБ1 и ЦБ3

# %%
# напишите свой код в этой ячейке, запустите машинку по маршруту, убедитесь, 
# что в конечной (и только в конечной!) точке CargoBay получает команду и успешно выполняет выгрузку

# %% [markdown]
# #### *Опциональное задание повышенной сложности* Обеспечение ЦБ2
#
# **Перед началом работы над этой задачей рекомендуем сохранить все текущие изменения в git репозитории (git commit, git push).**
#
# Напомним цель безопасности №2 (ЦБ2): "При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут"
#
# Обеспечение ЦБ2 потребует
# - внедрения механизма **контроля аутентичности маршрутного задания** (mission), а значит
# - помимо изменения **блока безопасности** (SafetyBlock), модификации
#   - системы **планирования задания** (MissionPlanner)
#   - **коммуникационного шлюза** (CommunicationGateway)
#   - и, возможно, **системы управления** (ControlSystem).
#
# Для решения этой задачи допустимо менять код соответствующих модулей в папке src.
#
# Возможным решением является внедрение механизма цифровой подписи, верификацией которой будет заниматься блок безопасности. В этой ситуации если коммуникационный шлюз (блок "1. Связь" на рис. 5 в модуле 1) оказался скомпрометированным и изменил маршрутное задание, оно не должно пройти проверку подлинности в блоке безопасности.
#
# **Рекомендуем эту задачу делать в последнюю очередь**, *после успешного выполнения модуля 4*, поскольку успешное выполнение модуля 4 принесёт больше баллов, чем внедрение цифровой подписи и обеспечение ЦБ2.
# К сведению, реализованные в этой версии киберпрепятствия не предполагают компрометацию маршрутного задания.
#
# Конечно, если будут решены все основные задачи и к тому же обеспечен контроль аутентичности маршрутного задания, такая работа с высокой вероятностью окажется лучшей.

# %%
# если вы собираетесь выполнить это задание, напишите в этой ячейке код выполнения изменённых блоков. 
# cам код допускается редактировать в папке src
# в случае успешной реализации машинка должна успешно пройти по маршруту, а в случае искажения маршрутного задания в блоке коммуникационного шлюза должна остаться на месте, 
# при этом именно блок безопасности должен заблокировать движение

# %% [markdown]
# ### Задание 3.2. Монитор безопасности

# %% [markdown]
# В текущей реализации каждый блок сам решает куда и какие данные ему отправлять. Это приемлемо, когда каждый блок рассматривается как благонадёжный. Однако нельзя исключать ситуацию успешной компрометации какого-либо из блоков (одного или нескольких), в результате которой злоумышленник может получить полный контроль над частью системы.
#
# В такой ситуации необходимо выстроить внутреннюю "поверхность защиты", частью этой системы уже является блок "Ограничитель", однако необходимо сделать так, чтобы соответствующие запросы проходили только через него, а не в обход.
#
# Для решения этой задачи необходимо добавить новый блок "Монитор безопасности". Его задача - обеспечить контроль направления информационных потоков, допустить передачу данных только между теми блоками и в тех направлениях, которые задуманы архитектором системы. Тогда, например, попытка передать команду из системы управления напрямую в сервоприводы в обход ограничителя будет заблокирована.
#
# Возможно, возникнет вопрос, а что помешает злоумышленнику отправить команду в обход этого монитора безопасности. В рамках этой учебной инфраструктуры особо ничего, однако при разработке реальной системы можно использовать специализированные микроядерные операционные системы, такие как, например, KasperskyOS, которые обеспечат обязательное вовлечение монитора безопасности в контроль взаимодействия между блоками.
#
# Архитектура системы для решения задачи 3.2 должна выглядеть как на рис.8:
#
# ![Архитектура системы с монитором безопасности](images/ciac-arch-m32.png)
#
# Рис. 8. Архитектура бортовых систем с монитором безопасности

# %% [markdown]
# Базовый класс модуля безопасности находится в файле src/security_monitor.py, его менять не нужно.
#
# В следующей ячейке находится реализация класса SecurityMonitor

# %%
from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import COMMUNICATION_GATEWAY_QUEUE_NAME, LOG_DEBUG, LOG_ERROR, LOG_INFO
    
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission')
        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized

# %% [markdown]
# Обратите внимание на этот код:
# ```python
#     def _init_set_security_policies(self):
#         """ инициализация политик безопасности """
#         default_policies = [
#             SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
#         ]
#         self.set_security_policies(policies=default_policies)
# ```
#
# В нём инициализируется политика безопасности, разрешающая запрос set_mission от коммуникационного шлюза в систему управления.
#
# Код политики безопасности в строка 6-9:
# ```python
# SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
# ```
#
# Шаблон политики безопасности описан в файле src/security_policy_type.py:
# ```python
# @dataclass
# class SecurityPolicy:
#     """ политика безопасности """
#     source: str         # отправитель запроса
#     destination: str    # получатель
#     operation: str      # запрашиваемая операция
#
# ```
#
# По аналогии в методе _init_set_security_policies допишите другие политики безопасности, чтобы разрешить взаимодействия согласно диаграмме на рис.7. выше.

# %% [markdown]
# Теперь необходимо изменить взаимодействие между блоками так, чтобы оно всегда проходило через монитор безопасности. Для этого потребуется изменить соответствующие реализации внутренних блоков.

# %% [markdown]
# Ниже пример для блока навигации. Обратите внимание на выделенные строки и комментарии.
#
# ```python
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         # событие для системы управления,
#         # поэтому в destination указываем CONTROL_SYSTEM_QUEUE_NAME
#         event = Event(source=self.event_source_name,
# >>>                      destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         # но событие отправляем сначала на проверку в монитор безопасности,
#         # поэтому используем очередь с именем SECURITY_MONITOR_QUEUE_NAME
# >>>        security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#         # а в систему управления наше событие монитор безопасности отправит сам, если найдёт разрешающую эту операцию политику безопасности
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)
# ```

# %% [markdown]
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         event = Event(source=self.event_source_name,
#                       destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)

# %% [markdown]
# В файле tests/module/test_security_monitor.py можно увидеть тест логики работы монитора безопасности. Запустить его можно следующей командой:

# %%
# !pytest -svk security_monitor
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.3, pytest-8.3.4, pluggy-1.5.0 -- /root/cyberimmune-autonomy--chvt-preview/env/bin/python3
# cachedir: .pytest_cache
# rootdir: /root/cyberimmune-autonomy--chvt-preview
# configfile: pytest.ini
# testpaths: tests
# collected 1 item
#
# tests/module/test_security_monitor.py::test_security_policies [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь security
# [ИНФО][SECURITY] создан монитор безопасности
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission')]
# [ОТЛАДКА][SECURITY] проверка события Event(source='communication', destination='control', operation='set_mission', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ОТЛАДКА][SECURITY] событие разрешено политиками, выполняем
# [ОТЛАДКА][SECURITY] проверка события Event(source='control', destination='safety', operation='set_speed', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission'), SecurityPolicy(source='control', destination='safety', operation='set_speed')]
# [ОТЛАДКА][SECURITY] проверка события Event(source='control', destination='safety', operation='set_speed', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ОТЛАДКА][SECURITY] событие разрешено политиками, выполняем
# [ОТЛАДКА][SECURITY] проверка события Event(source='communication', destination='cargo', operation='release_cargo', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# PASSED
#
# ============================== 1 passed in 0.01s ===============================

# %% [markdown]
# В одном кодовом блоке ниже (или нескольких - как будет удобнее)  сделайте следующее
#
# 1. Измените реализацию монитора безопасности в части правил проверки передаваемых сообщений в мониторе безопасности
# 2. Измените параметры отправки сообщений между элементами бортовых систем (блоками 1-7), чтобы они всегда отправлялись в очередь монитора безопасности (отправитель и получатель при этом не меняются)
# 3. После всех изменений убедитесь в том, что машинка по-прежнему успешно выполняет маршрутное задание и доставляет груз
# 4. Дополнительные баллы принесут автоматические тесты правил безопасности в файле tests/module/test_security_monitor.py - можно проверить, что все новые политики работают как ожидаются, а недопустимые взаимодействия (т.е. таких стрелок нет на рис. 8) блокируются

# %%
# добавьте изменения сюда

from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import *
    
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission'),
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="set_mission"),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=NAVIGATION_QUEUE_NAME,
                operation="request_position"),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="position_update"),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation="position_update"),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="set_speed"),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="set_direction"),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation="set_speed"),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation="set_direction"),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation="release_cargo"),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation="lock_cargo")
        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized

# %%
from src.safety_block import BaseSafetyBlock
from src.config import *
import math
from time import sleep
from geopy import Point as GeoPoint
from src.config import LOG_ERROR, LOG_INFO, LOG_DEBUG
from multiprocessing import Queue
from src.config import SERVOS_QUEUE_NAME
from src.event_types import Event


# 2. напишите в этом блоке реализацию изменённых блоков связи, управления и навигации, 
# чтобы передавать данные согласно изменённой архитектуре на рис. 5 для обеспечения работы по сценарию на рис.6

# вставьте сюда ваш код
from src.control_system import BaseControlSystem
from src.navigation_system import BaseNavigationSystem
from src.communication_gateway import BaseCommunicationGateway
from multiprocessing import Queue
from src.config import SAFETY_BLOCK_QUEUE_NAME
from src.config import SERVOS_QUEUE_NAME
from src.config import CONTROL_SYSTEM_QUEUE_NAME
from src.event_types import Event


class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_speed", parameters=speed
                    ) # замените на код создания сообщения со скоростью для приводов
                           # подсказка, требуемая операция - set_speed

        # отправка сообщения с желаемым направлением
        event_direction = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_direction", parameters=direction
                    ) # замените на код создания сообщения с направлением для приводов
                               # подсказка, требуемая операция - set_direction

        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event_direction)
        security_monitor_q.put(event_speed)
        
    def _lock_cargo(self):
        """ заблокировать грузовой отсек """
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                    destination=SAFETY_BLOCK_QUEUE_NAME,
                    operation="lock_cargo", parameters= None
                    )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME, 
                    destination=SAFETY_BLOCK_QUEUE_NAME,
                    operation="release_cargo", parameters= None
                    )  
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)


class CommunicationGateway(BaseCommunicationGateway):
    """CommunicationGateway класс для реализации логики взаимодействия
    с системой планирования заданий

    Работает в отдельном процессе, поэтому создаётся как наследник класса Process
    """
    def _send_mission_to_consumers(self):
        """ метод для отправки сообщения с маршрутным заданием в систему управления """
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)
                
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)


class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):        
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="position_update", parameters=self._position
                      )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)
      
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        event =  Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="position_update", parameters=self._position
                    ) # замените на код создания сообщения с координатами для системы управления 
                     # подсказка, требуемая операция - position_update
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)

class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        # TODO реализовать контроль безопасности изменения направления

        if not self._position or not self._route:
            return
        
        current = self._position
        next = self._route.next_point()
        bearing = self._calculate_bearing(current, next)
        
        direction = max(bearing - 5, min(bearing + 5, direction))
                
        self._direction = direction
        # отправка сообщения с желаемым направлением
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        if not self._route:
            return

        speed = max(0, min(speed, self._route.calculate_speed()))

        self._speed = speed
        self._send_speed_to_consumers()

    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event_speed)

    def _lock_cargo(self, _):
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._send_lock_cargo_to_consumers()

    def _send_lock_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду блокировки в CargoBay")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="lock_cargo",
            parameters=None
        )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)
        
    def _release_cargo(self, _):
        if not self._route or not self._route.route_finished:
            return
        self._send_release_cargo_to_consumers()

    def _send_release_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду выгрузки в CargoBay")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="release_cargo",
            parameters=None
        )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)

    def _calculate_bearing(self, start: GeoPoint, end: GeoPoint):
        delta_longitude = end.longitude - start.longitude
        x = math.sin(math.radians(delta_longitude)) * \
            math.cos(math.radians(end.latitude))
        y = math.cos(math.radians(start.latitude)) * math.sin(math.radians(end.latitude)) - \
            math.sin(math.radians(start.latitude)) * math.cos(math.radians(end.latitude)) * \
            math.cos(math.radians(delta_longitude))
        initial_bearing_rad = math.atan2(x, y)

        # Преобразуем радианы в градусы
        initial_bearing_deg = math.degrees(initial_bearing_rad)

        # Нормализуем значение в диапазоне [0, 360]
        compass_bearing = (initial_bearing_deg + 360) % 360

        return compass_bearing

# %% [markdown]
# На этом модуль 3 завершён!
#
# Если у вас всё получилось, то вы создали защищённую автономную машинку - ещё уже не так-то просто использовать для нанесения критического ущерба людям и имуществу, потому что самые критические режимы проверяются вашим Ограничителем, а если вы ещё и внедрили Монитор Безопасности, то теперь злоумышленнику гораздо сложнее атаковать внутренние блоки, даже если он смог проникнуть в какую-то бортовую систему или внедрить вредоносный код.
#
# Осталось проверить эффективность получившейся защиты на полной трассе - в этом и заключается модуль 4 задания, для перехода к которому нужно открыть блокнот с именем cyberimmunity--autonomous-car-m4. Успеха!
